# %%
import string
import random
import torch
import torch.nn as nn
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %%
all_chars       = string.printable
n_chars         = len(all_chars)
file            = open('./cnus.txt').read()
file_len        = len(file)

print('Length of file: {}'.format(file_len))
print('All possible characters: {}'.format(all_chars))
print('Number of all possible characters: {}'.format(n_chars))
# Out:
# Length of file: 3381928
# All possible characters: 0123456789abcdefghijklmnopqrstuvwxyzABCDEFGHIJKLMNOPQRSTUVWXYZ!"#$%&'()*+,-./:;<=>?@[\]^_`{|}~
#
# Number of all possible characters: 100

# %%
# Remove all non-printable characters
file = ''.join(list(filter((lambda x: x in all_chars), file)))

# %%
file_len = len(file)
print('Length of file: {}'.format(file_len))
# Out:
# Length of file: 3381831

# %%
# Get a random sequence of the Sherlock dataset.
def get_random_seq():
    seq_len     = 128  # The length of an input sequence.
    start_index = random.randint(0, file_len - seq_len)
    end_index   = start_index + seq_len + 1
    return file[start_index:end_index]

# Convert the sequence to one-hot tensor.
def seq_to_onehot(seq):
    tensor = torch.zeros(len(seq), 1, n_chars) 
    # Shape of the tensor:
    #     (sequence length, batch size, classes)
    # Here we use batch size = 1 and classes = number of unique characters.
    for t, char in enumerate(seq):
        index = all_chars.index(char)
        tensor[t][0][index] = 1
    return tensor

# Convert the sequence to index tensor.
def seq_to_index(seq):
    tensor = torch.zeros(len(seq), 1)
    # Shape of the tensor: 
    #     (sequence length, batch size).
    # Here we use batch size = 1.
    for t, char in enumerate(seq):
        tensor[t] = all_chars.index(char)
    return tensor

# Sample a mini-batch including input tensor and target tensor.
def get_input_and_target():
    seq    = get_random_seq()
    input  = seq_to_onehot(seq[:-1])      # Input is represented in one-hot.
    target = seq_to_index(seq[1:]).long() # Target is represented in index.
    return input, target

# %%
# If there are GPUs, choose the first one for computing. Otherwise use CPU.
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
print(device)  
# If 'cuda:0' is printed, it means GPU is available.
# Out:
# cuda:0

# %%
class Net(nn.Module):
    def __init__(self, activation='RNN'):
        # Initialization.
        super(Net, self).__init__()
        self.input_size  = n_chars   # Input size: Number of unique chars.
        self.hidden_size = 100       # Hidden size: 100.
        self.output_size = n_chars   # Output size: Number of unique chars.
        
        self.linear = nn.Linear(self.hidden_size, self.output_size)
        if activation == 'RNN':
            self.activation = nn.RNNCell(self.input_size, self.hidden_size)
        elif activation == 'LSTM':
            self.activation = nn.LSTMCell(self.input_size, self.hidden_size)
        
        self.act = activation
            
    def forward(self, input, hidden):
        if self.act == 'RNN':
            hidden = self.activation(input, hidden)
            output = self.linear(hidden)
            return output, hidden
        else:
            hidden, cell = self.activation(input, hidden)
            output = self.linear(hidden)
            return output, hidden, cell

    def init_hidden(self):
        # Initial hidden state.
        # 1 means batch size = 1.
        return torch.zeros(1, self.hidden_size).to(device) 
    
    def init_cell(self):
        # Initial cell state.
        # 1 means batch size = 1.
        return torch.zeros(1, self.hidden_size).to(device)

# %%
# Training step function.
def train_step(net, opt, input, target):
    seq_len = input.shape[0]    # Get the sequence length of current input.
    hidden = net.init_hidden()  # Initial hidden state.
    cell = net.init_cell()      # Initial cell state
    net.zero_grad()             # Clear the gradient.
    loss = 0                    # Initial loss.
    
    if net.act == 'RNN':
        for t in range(seq_len):    # For each one in the input sequence.
            output, hidden = net(input[t], hidden)
            loss += loss_func(output, target[t])
    else:
        for t in range(seq_len):    # For each one in the input sequence.
            output, hidden, cell = net(input[t], (hidden, cell))
            loss += loss_func(output, target[t])

    loss.backward()             # Backward. 
    opt.step()                  # Update the weights.

    return loss / seq_len       # Return the average loss w.r.t sequence length.

# %%
# Evaluation step function.
def eval_step(net, init_seq='W', predicted_len=100):
    # Initialize the hidden state, input and the predicted sequence.
    hidden        = net.init_hidden()
    cell          = net.init_cell()
    init_input    = seq_to_onehot(init_seq).to(device)
    predicted_seq = init_seq

    # If input net is RNN
    if net.act == 'RNN':
        # Use initial string to "build up" hidden state.
        for t in range(len(init_seq) - 1):
            output, hidden = net(init_input[t], hidden)
        # Set current input as the last character of the initial string.
        input = init_input[-1]
        
        # Predict more characters after the initial string.
        for t in range(predicted_len):
            # Get the current output and hidden state.
            output, hidden = net(input, hidden)
        
            # Sample from the output as a multinomial distribution.
            predicted_index = torch.multinomial(output.view(-1).exp(), 1)[0]
        
            # Add predicted character to the sequence and use it as next input.
            predicted_char  = all_chars[predicted_index]
            predicted_seq  += predicted_char
        
            # Use the predicted character to generate the input of next round.
            input = seq_to_onehot(predicted_char)[0].to(device)
    
    # If input net is LSTM       
    else:
        # Use initial string to "build up" hidden state.
        for t in range(len(init_seq) - 1):
            output, hidden, cell = net(init_input[t], (hidden, cell))
        # Set current input as the last character of the initial string.
        input = init_input[-1]
        
        # Predict more characters after the initial string.
        for t in range(predicted_len):
            # Get the current output and hidden state.
            output, hidden, cell = net(input, (hidden, cell))
        
            # Sample from the output as a multinomial distribution.
            predicted_index = torch.multinomial(output.view(-1).exp(), 1)[0]
        
            # Add predicted character to the sequence and use it as next input.
            predicted_char  = all_chars[predicted_index]
            predicted_seq  += predicted_char
        
            # Use the predicted character to generate the input of next round.
            input = seq_to_onehot(predicted_char)[0].to(device)

    return predicted_seq

# %% [markdown]
# ### Experiment

# %%
# Perform n_trials each for standard RNN and LSTM.

n_trials    = 3      # Number of trials per model
iters       = 20000  # Number of training iterations per trial.
print_iters = 100    # Number of iterations for each log printing.

# %%
# The loss variables.
all_losses_rnn = np.zeros(int(iters / print_iters))

# Training procedure.
for i in range(n_trials):
    net_rnn = Net()     # Create a new network instance.
    net_rnn.to(device)
    opt_rnn       = torch.optim.Adam(net_rnn.parameters(), lr=0.005)
    loss_func = nn.CrossEntropyLoss()
    losses = np.array([])
    loss_sum = 0
    for j in range(iters):
        input, target = get_input_and_target()            # Fetch input and target.
        input, target = input.to(device), target.to(device) # Move to GPU memory.
        loss      = train_step(net_rnn, opt_rnn, input, target)   # Calculate the loss.
        loss_sum += loss.item()                                  # Accumulate the loss.

        # Print the log.
        if j % print_iters == print_iters - 1:
            print('rnn_trial:{}, iter:{}/{} loss:{}'.format(i, j, iters, loss_sum / print_iters))
            print('generated sequence: {}\n'.format(eval_step(net_rnn)))
              
            # Track the loss.
            losses = np.append(losses, loss_sum / print_iters)
            loss_sum = 0
    all_losses_rnn += losses
    
mean_losses_rnn = all_losses_rnn / n_trials
# Out:
# rnn_trial:0, iter:99/20000 loss:3.0453678870201113
# generated sequence: Wagpotiinven   . t,  aI   y ,I !   e  oy ub  cpdhronie ntit ieso,yit , gmt  o h we     tgs hkid   csl
#
# rnn_trial:0, iter:199/20000 loss:2.6619764256477354
# generated sequence: W:T  oill
#   e  t  n.        ar, wanall  the Matoee-poy e
#   a   he .ouuethae
#   haznthond the the by sh
#
# rnn_trial:0, iter:299/20000 loss:2.4562177658081055
# generated sequence: Wion aave on  " yor  cn chan l not  toesm toumed ibesd im sors gonod fes the rars yhcose me, d oottis
#
# rnn_trial:0, iter:399/20000 loss:2.30515665769577
# generated sequence: Wer ird anger o  " The yas  an fturker. w  ixtlejmy thesmarve The iit, ind berkend
#
#       p Cbe ghe
#
# rnn_trial:0, iter:499/20000 loss:2.2440952694416048
# generated sequence: Warpume, oon, "Are acas fram has Mpdaved wis It melat tr; germy Er coHes."
# f    Shanvedvusmal sopidga
#
# rnn_trial:0, iter:599/20000 loss:2.1691305911540986
# generated sequence: Waredkamy usous mousasteld
# ,    "
#  " y sor, angrouts muste sufv,d."
#
#      Oxyroof adenyoupteg lyot lr
#
# rnn_trial:0, iter:699/20000 loss:2.140593328475952
# generated sequence: Wilt a das, from to the slinich torlo lyro ald tem qum lith a lof qlean th slas, somnee
#      med cont
#
# rnn_trial:0, iter:799/20000 loss:2.08072234749794
# generated sequence: We istcaintube weans. hy the mjeeded. Iy ce thistibyes t in dougwete yourd hild conted fainled
#      s
#
# rnn_trial:0, iter:899/20000 loss:2.0617997109889985
# generated sequence: Wetthinl. He as a douCt. The exsaod Thingas shid an's' festals."
#
#      "At sirld apl pur mas's and
#
#
# rnn_trial:0, iter:999/20000 loss:2.0489547979831695
# generated sequence: With
#      wiid
#      f het ofspinio tthern kouncte som sovirteturut tro couse ssert
#      sod vieg. I t
#
# rnn_trial:0, iter:1099/20000 loss:2.018322756290436
# generated sequence: We naces Go mobsone, Mill bas
#  t   forinntictore
#      as ie sersensith you drolpe humile pulhed mo
#
#
# rnn_trial:0, iter:1199/20000 loss:1.9697691881656647
# generated sequence: Whed and mistsing ald brannty teked's, frookniss my."
#
#      "Holedyiorter?"
#
#      "I sook the eoulys,
#
# rnn_trial:0, iter:1299/20000 loss:1.9805979108810425
# generated sequence: Wids oofarg- fao noa. Il some ro fave
#      fogreet his
#      of Shoums
#      ins'ed oStore foop way ure
#
# rnn_trial:0, iter:1399/20000 loss:1.9447111368179322
# generated sequence: Wolmel be concence the intigid the has ore undser wisksestext. To in the comer?"
#      "Watwer wou kas
#
# rnn_trial:0, iter:1499/20000 loss:1.9440822410583496
# generated sequence: Wo Dake of actibt whien on."A
#      ove im sowseall igness barl tor gas
#      wiss me dopation intherus
#
# rnn_trial:0, iter:1599/20000 loss:1.9036397016048432
# generated sequence: Whinty in an in,  crimane imamion your fegteren tore
#      the
#      my beled cronen thank of our."The
#
# rnn_trial:0, iter:1699/20000 loss:1.949333587884903
# generated sequence: We so ve mourlang the lages--be atrour a sabe munreh shad
#      rearglith?o?      You hannt whelest he
#
# rnn_trial:0, iter:1799/20000 loss:1.920474090576172
# generated sequence: Wcon--at in rotne
#      iuste.
#
#      "Cad, were cone,
#      Me, was ifnd shat of ay yout haviaghid you!
#
# rnn_trial:0, iter:1899/20000 loss:1.910206197500229
# generated sequence: We round.  I aividing of we treplest if habked gilwitt."
#
#      Fray iain, mut to
#      roups ane nourl
#
# rnn_trial:0, iter:1999/20000 loss:1.8957775676250457
# generated sequence: Wall werd quirl
#      the deatlard atcrugd-gaglt hart. Whand that thith toll at is shot
#      grime?"
#
# rnn_trial:0, iter:2099/20000 loss:1.9011757314205169
# generated sequence: We hos sjots hime owe wo meapeabers anougy be be knof and on
#      suknem, But lever to fow.
#
#      "'Y
#
# rnn_trial:0, iter:2199/20000 loss:1.8724388933181764
# generated sequence: Wide. I mely terly byon spaus. th the canse work a Toban pHow ixsaiced.
#
#      "Ay whseledck the Then
#
# rnn_trial:0, iter:2299/20000 loss:1.8675491142272949
# generated sequence: Wet me to to the might pustoblichen a tatibel, we gome hear imed, and Hollew of thish pous, in a mong
#
# rnn_trial:0, iter:2399/20000 loss:1.8756597101688386
# generated sequence: We bell?"
#
#      Itrre were Jancol.
#
#      "I tin pracce.' had us
#      do. "A, undy in ering ablared se
#
# rnn_trial:0, iter:2499/20000 loss:1.8818126952648162
# generated sequence: Well, what
#      id den and as Ores hished not not had sad ste priet in over whiy Yot kest masred I it
#
# rnn_trial:0, iter:2599/20000 loss:1.8464327347278595
# generated sequence: Whath festons thly grnech, and thin befn imetsing thet the andes. I sawe sandeits und in upemeh, stin
#
# rnn_trial:0, iter:2699/20000 loss:1.8402900838851928
# generated sequence: Where sinst a
#      whech purter impors, and to chall sanon shaskhed a dowert the cropere, amd I thes
#
# rnn_trial:0, iter:2799/20000 loss:1.8605914866924287
# generated sequence: We sook.
#
#
#      his ever canded of that con
#      got Hold. It have giding at have oo awime.
#
#      How
#
# rnn_trial:0, iter:2899/20000 loss:1.8412746691703796
# generated sequence: Willl a mady themsed lare ill the lave."
#
#      "Oumed have
#      chir hot hauld plaitsy ofand
#      cas
#
# rnn_trial:0, iter:2999/20000 loss:1.8287268590927124
# generated sequence: We arain onow anrrank't
#      agring vis haice fown stooved."Y
#      "They her,
#      Slack
#      worker.
#
# rnn_trial:0, iter:3099/20000 loss:1.8150433647632598
# generated sequence: Whintlotely
#      by new, selly
#      a letele," I retorny to thinh
#      the care by werne, herlert haw
#
# rnn_trial:0, iter:3199/20000 loss:1.8442342531681062
# generated sequence: Wighn sprect you shountr a to know a scight
#      knen wo te he have fow which of t - f Is Missly if w
#
# rnn_trial:0, iter:3299/20000 loss:1.8186444985866546
# generated sequence: Watsoun came thatazre. No gilked Mr. Ce tomes im."
#
#      "Vill thlughid lator Goon the
#      a very th
#
# rnn_trial:0, iter:3399/20000 loss:1.8281938934326172
# generated sequence: We is and I winchort quir ce, shell but is unde one
#      happebed, slloch
#      I weelf sher
#      Hole
#
# rnn_trial:0, iter:3499/20000 loss:1.792276451587677
# generated sequence: Waow, the hindil this ey
#      ecor hand suds! I up in
#      uctided him?"
#
#      "Yes, in of pantired i
#
# rnn_trial:0, iter:3599/20000 loss:1.839626520872116
# generated sequence: We he deather then cormann?"
#      that that have beateored, buched of have a mays he brainly and were
#
# rnn_trial:0, iter:3699/20000 loss:1.8277870154380798
# generated sequence: We af this saip sonfysu, as his fapperod oor, "     "I havo my semeneny to nood sidus dan' herd in no
#
# rnn_trial:0, iter:3799/20000 loss:1.8665712034702302
# generated sequence: Wise theme
#      blind had's, this exfoaderlid betwell, rertherinticined lut the intuind
#      had you
#
# rnn_trial:0, iter:3899/20000 loss:1.8387978863716126
# generated sequence: When! I
#      Frominispeep a cerented randed of exceg
#      myrentiiqlencest. Inse
#      it hir the soon
#
# rnn_trial:0, iter:3999/20000 loss:1.7944778907299042
# generated sequence: Wam."
#
#      Ho
#
#     upen
#      shape. The wive, to that ad sime thin misezing."
#
#      "Stores ge sach
#
# rnn_trial:0, iter:4099/20000 loss:1.83683584690094
# generated sequence: Wile apper the been. "I have difark riiv.
#
#      "Whate dand cloilas tried is olvired to Effed om ey f
#
# rnn_trial:0, iter:4199/20000 loss:1.8176961064338684
# generated sequence: Waicls sce be pustiless weed flred us fooly, arg and be onl oar in a rapeswaotert hould eare were pri
#
# rnn_trial:0, iter:4299/20000 loss:1.762204030752182
# generated sequence: We him.
#
#      "-been us the can oe wore so yous laft same was ase soce."
#
#      "'Suldlery trat,
#
#
# rnn_trial:0, iter:4399/20000 loss:1.7787098681926727
# generated sequence: We, Ard him the is at the Lerkened of whe benter dign that instling and sert oft futht the downy at t
#
# rnn_trial:0, iter:4499/20000 loss:1.7751449739933014
# generated sequence: Which is vot or as so? Ho fay
#      sa dot that pe, and a man
#      was omerowarver a suadls who has Be
#
# rnn_trial:0, iter:4599/20000 loss:1.7733803176879883
# generated sequence: Wouth aflergasthe ampses ham there makestlagoeedy
# ,    "No. SIiwer I can soucter an. The pardt, wande
#
# rnn_trial:0, iter:4699/20000 loss:1.7901192212104797
# generated sequence: Wawe of weif tho furdothition.
#
#      "Ther, I cast, then in "Sing then I wand wonded then dimy Condip
# rnn_trial:0, iter:4799/20000 loss:1.784737113714218
# generated sequence: We hop und."
#
#      "Shrom
#      I satuenes, we thing encaice of is soming think housen
#      otlided th
#
# rnn_trial:0, iter:4899/20000 loss:1.7682650780677795
# generated sequence: We sat for
#      cunnnys yex
#      it is a rave that a dound. "My dare
#      avoraselond peverfelyels ip
#
# rnn_trial:0, iter:4999/20000 loss:1.7756156539916992
# generated sequence: We as my
#      me the laich or tabe saans. Sirured almusincer
#      quitting reose his emplike. As. "In
#
# rnn_trial:0, iter:5099/20000 loss:1.8019653964042663
# generated sequence: Wieds he have  frosted like do could becooton whuming up."
#
#      "Wet
#      wher, and of intital the r
#
# rnn_trial:0, iter:5199/20000 loss:1.791430366039276
# generated sequence: Wer fienly.
#      Nontaigais in the wank an cank coneed the treqhery hare with "rest was nother onges
#
# rnn_trial:0, iter:5299/20000 loss:1.7614681017398834
# generated sequence: Was peastle ary
#      facte," he hea the hurvertato that that that out her sand thould.
#
#      My fache
#
# rnn_trial:0, iter:5399/20000 loss:1.767686779499054
# generated sequence: Wave sikl that when tu fill clast, bres of the sonk very that ee have timt bugn farms to styrre way s
#
# rnn_trial:0, iter:5499/20000 loss:1.7106579220294953
# generated sequence: We saicing implect Charring ip my is
#      the gut where clasping had rook, and which I ."ALd of you h
#
# rnn_trial:0, iter:5599/20000 loss:1.7674943935871124
# generated sequence: Wettanatidy, profter they his purght, we ently the molmestible trowl. There angen
#      the morns upon
#
# rnn_trial:0, iter:5699/20000 loss:1.7690984320640564
# generated sequence: Whaw of the Mame this, caund that I thas this a's surpeed the count gees oustiond
#      ismagapand hea
#
# rnn_trial:0, iter:5799/20000 loss:1.774764095544815
# generated sequence: Wies, acraghingerseevary, are
#      cuater I him no beration everent deigst of has nateng of the marde
#
# rnn_trial:0, iter:5899/20000 loss:1.7381791186332702
# generated sequence: Wirco aceutuase
#      medthidoweer a ochnopanied,
#      a clofoe?"
#
#      "Ithinet the crown at to mepio
#
# rnn_trial:0, iter:5999/20000 loss:1.7376893627643586
# generated sequence: We Sacsthen there sastinging in the manal thought Batter, was to unding-alrame, Mill cashaint in us s
#
# rnn_trial:0, iter:6099/20000 loss:1.779811317920685
# generated sequence: We amrove you abvery that in not of is you her touth ie Vind to gron's belone if rur here which his f
#
# rnn_trial:0, iter:6199/20000 loss:1.78334867477417
# generated sequence: We oor I'tsee it in med mark enace. A friat clay's catrol dary agrtume ubdy,
#      click as uply wess
#
# rnn_trial:0, iter:6299/20000 loss:1.7613495373725891
# generated sequence: Whicure numble, and as
#
#    Mresiden
#      tut noncy founder knowane Arland, was nog digs.
#
#      "An
#
# rnn_trial:0, iter:6399/20000 loss:1.7428593707084656
# generated sequence: We
#      unce of do
#      on thru.' tads.
#
#      "I'll righto amarol a wandon
#      sties a quis. Mut thi
#
# rnn_trial:0, iter:6499/20000 loss:1.7342885273694992
# generated sequence: What
#      to'sher of know any that
#      corsed," sainy thiw
#      otetaily on tor. In nare, and bether
#
# rnn_trial:0, iter:6599/20000 loss:1.7522392523288728
# generated sequence: Wes we had coom had suy out for it is
#      upon an endee of emboour for seronge, take opfe to morcoum
#
# rnn_trial:0, iter:6699/20000 loss:1.7511963081359863
# generated sequence: We lent,
#      neartion Hall-by at
#      2Bingabed of prised who vibare. He proper; but
#      nerppectir
#
# rnn_trial:0, iter:6799/20000 loss:1.7490709125995636
# generated sequence: Whe reemer, who
#      a cance verituriesait his sin the folfablet uppound a garging as he willlegnt? H
#
# rnn_trial:0, iter:6899/20000 loss:1.7437774431705475
# generated sequence: Wad
#      the key airegsurats and beekered a could famigger fellingridit and here wa the c6att fuom. I
#
# rnn_trial:0, iter:6999/20000 loss:1.7532030200958253
# generated sequence: Warlock in the
#      he coarite as a stre of
#      dryes of with d more, arring of
#      reat weme brear
#
# rnn_trial:0, iter:7099/20000 loss:1.7136680817604064
# generated sequence: Wher he dow you Jundses; I me the
#      wask of my. I he leeseced hims peites, it hamftran well the Mr
#
# rnn_trial:0, iter:7199/20000 loss:1.7399811255931854
# generated sequence: Wh sabenca
#      paiehed the crevaue.
#
#      "Jet up up more hot who Mf is mage could he cans his my ti
#
# rnn_trial:0, iter:7299/20000 loss:1.7031695938110352
# generated sequence: Way non, mannic colleted,
#      rank clort take and who lound so
#      know sowet me of the Must walk-w
#
# rnn_trial:0, iter:7399/20000 loss:1.6971771001815796
# generated sequence: We it that in
#      twaice."
#
#      The cale all becout though that upon outhing of Byston, ind I shisk
#
# rnn_trial:0, iter:7499/20000 loss:1.7732807910442352
# generated sequence: We dlo men the curs that so an abol a waiterver of our sagureiall have
#      mey hip, insely bemorts t
#
# rnn_trial:0, iter:7599/20000 loss:1.7602451419830323
# generated sequence: Wa she courner hhall,, and the -"Grif-legng
#      had been pereannes.
#
#      "You caper ir. Assoused.
#
#
# rnn_trial:0, iter:7699/20000 loss:1.7515070819854737
# generated sequence: Whtaly gath, becamunterle had f couzce when sterlect look of him-sidl be incallt, and in would his
#
#
# rnn_trial:0, iter:7799/20000 loss:1.757153376340866
# generated sequence: We to mine, her dan as a
#      camed the comfick a arith, rutftaicerduld, for there tender dones was t
#
# rnn_trial:0, iter:7899/20000 loss:1.7301781904697418
# generated sequence: Westur come. But ole and the moss to seem. I cases. It and refpition mast exters at."
#
#      "He the r
#
# rnn_trial:0, iter:7999/20000 loss:1.7414838314056396
# generated sequence: We. The twong paclioncant, Be oud of themes hake ils untol would Meds lootperneted brught of the nutw
#
# rnn_trial:0, iter:8099/20000 loss:1.736423715353012
# generated sequence: Wher an
#      and hakes in strrange in on Tracing, thair camcing is clead, cringst read the long, I wa
#
# rnn_trial:0, iter:8199/20000 loss:1.6695107704401015
# generated sequence: We without, all the wast, with botter, ence his
#      would be a bie' I without lot brow," said inver
#
# rnn_trial:0, iter:8299/20000 loss:1.728783608675003
# generated sequence: We you the deticed trace is which sose mammiving hald a mast me ababse win covely juvent with to
#
#
# rnn_trial:0, iter:8399/20000 loss:1.7121363592147827
# generated sequence: We that despare lownhous noand gook, a frieningwowfen-oby which I shirlible. I hishbess of the srickl
#
# rnn_trial:0, iter:8499/20000 loss:1.722928512096405
# generated sequence: Whar. Thinh a
#      be mind the formancions done aware, the
#      ofert all pas.
#
#      "Nover of when h
#
# rnn_trial:0, iter:8599/20000 loss:1.7252363908290862
# generated sequence: Well plighirig Lany whakber, to fitwns.
#
#      " A loynt ensayil lose your listlass in the matthers to
#
# rnn_trial:0, iter:8699/20000 loss:1.718490434885025
# generated sequence: Way his but and the prision. It to the
#      tave hell we looke at wone it."
#
#      "E'llous everionde
#
# rnn_trial:0, iter:8799/20000 loss:1.7143874418735505
# generated sequence: We no rethangraintred aftay tcat Mrenisy
#      the went what resiig a swand was to baid against
#      h
#
# rnn_trial:0, iter:8899/20000 loss:1.7330227434635161
# generated sequence: Welt treen He, Mrys has betser spees for these
#      ciles-with intelver plack longer we well, befortt
#
# rnn_trial:0, iter:8999/20000 loss:1.726311398744583
# generated sequence: Weltured work? whel en as po. Then lidtion whith foow I ala's sey seid hart. The sthaks ano. Tall
#
#
# rnn_trial:0, iter:9099/20000 loss:1.730225110054016
# generated sequence: Whin in speam in this explougly wive think hour contite inteamed houbly--gelt-blenom is quede
#      ar
#
# rnn_trial:0, iter:9199/20000 loss:1.7228141355514526
# generated sequence: Whords, but he
#      the let Blougred at
#      langelf. "The
#      indock tall clragoan tome rether the
#
# rnn_trial:0, iter:9299/20000 loss:1.7180372452735901
# generated sequence: Whernil thot of her goffur excloot, than to geathan, with your, and to the ngres. On to
#      Roy to m
#
# rnn_trial:0, iter:9399/20000 loss:1.6832390856742858
# generated sequence: We manmes. There you dowed
#      ben
#      to tunted of avil,
#      looking nothing to
#      see to comen
# rnn_trial:0, iter:9499/20000 loss:1.7119554734230042
# generated sequence: We murded sed. I themrsill, the she laky gew gose see it were dobrex, in 1878vers, Dread. I sadinibly
#
# rnn_trial:0, iter:9599/20000 loss:1.6809455335140229
# generated sequence: We presion. His raster own, and earch with my way ead at to me domen mudd als was then it me iminal l
#
# rnn_trial:0, iter:9699/20000 loss:1.7011205577850341
# generated sequence: Wen tyes. You hersonger upoune with her."
#
#      "rut objeam are congin, for stercheserder one
#      at
#
# rnn_trial:0, iter:9799/20000 loss:1.724785521030426
# generated sequence: We told off to stight to beepmening amp quenou dment feleg would what to upon a veAt had yeits a quin
#
# rnn_trial:0, iter:9899/20000 loss:1.7158613693714142
# generated sequence: Whensured, was
#      an a amyand any with and may with with the clittly.
#
#      "And her if a tabling a
#
# rnn_trial:0, iter:9999/20000 loss:1.7135740053653716
# generated sequence: Whencoresterure Mrireed. If
#          Chareticlell, latter Rand rerle. Or the Ruture torselver,
#      t
#
# rnn_trial:0, iter:10099/20000 loss:1.7122937715053559
# generated sequence: When have of a strussed my you on Sromptand for the bound linger houghila kned Loterny would rement t
#
# rnn_trial:0, iter:10199/20000 loss:1.6944237411022187
# generated sequence: When the
#      fines was at Starp of
#      ageed lackire endully enirua."
#
#      "There sar. You do on a
#
# rnn_trial:0, iter:10299/20000 loss:1.6650164794921876
# generated sequence: We it the 'I Mr. Sir cristle deason, the durros. In the edvintiat, themend plovid owreterd. One encid
#
# rnn_trial:0, iter:10399/20000 loss:1.6643111288547516
# generated sequence: Whing that by pess the clust shan shale. I clull magers to the
#      cinter
#      cir upon give
#      le
#
# rnn_trial:0, iter:10499/20000 loss:1.7013875329494477
# generated sequence: When whith he hards be to ack sasks self awners hed he comply
#      the tell I seres in probse intsit,
#
# rnn_trial:0, iter:10599/20000 loss:1.7172936832904815
# generated sequence: We hose im with nof churs--bark, and not lattenest?"
#
#      "Bert. "That neat wouked mumbrounch, oo tw
#
# rnn_trial:0, iter:10699/20000 loss:1.6900936627388001
# generated sequence: We with the vall in importmed I tose betor in
#      as his see from the toil you may of with notharden
#
# rnn_trial:0, iter:10799/20000 loss:1.7009951853752137
# generated sequence: Wellow said likely is
#      him trauld will came to the peraualmes, apsing on the recee the reDone roa
#
# rnn_trial:0, iter:10899/20000 loss:1.7218366765975952
# generated sequence: White than to
#      howed, in him be Toon was into his himplinqoact celighelf. At we dearlicion! Yot s
#
# rnn_trial:0, iter:10999/20000 loss:1.6861239922046662
# generated sequence: When two noter,"'s all an one in the heaply cout have a ha han shrint, can man and band becams that o
#
# rnn_trial:0, iter:11099/20000 loss:1.7300279498100282
# generated sequence: Wadd
#      womate to get I frose in the nase. Negge to the brack. He. As so, gropy o
#      stang
#
# h  s
#
# rnn_trial:0, iter:11199/20000 loss:1.7286849546432494
# generated sequence: White bouct and him hownesper, and the pooff upsed sever came half."
#      hosment witly faing the exp
#
# rnn_trial:0, iter:11299/20000 loss:1.703010116815567
# generated sequence: When time It instout s woice?"
#      I should, Wats for the ring
#      tnat littow of them unterr for a
#
# rnn_trial:0, iter:11399/20000 loss:1.7179974400997162
# generated sequence: Wamdy to dost a good, and the stractid themd trus coor calent. Cot if rnoun
#      evilless hurmath unt
#
# rnn_trial:0, iter:11499/20000 loss:1.7085999274253845
# generated sequence: We rownate--ey.' There in not Nold tark no the earled is a stean tand his willess that is. I was is.
#
# rnn_trial:0, iter:11599/20000 loss:1.7200387060642242
# generated sequence: Wire loy'ferand note. Bemimes.
#
#      "The's at leaty
#      eift it ene
#      had bro-stape. But he con.
#
# rnn_trial:0, iter:11699/20000 loss:1.6843729841709136
# generated sequence: We thoncele to for moriilf dif out is of surle tellus to At it.
#
#      "Thing was why gave talf bo cle
#
# rnn_trial:0, iter:11799/20000 loss:1.671592606306076
# generated sequence: Wive would
#      in the Lerromes wit of to and sto twollow as her fach I mady missed.w
#      was diotid
#
# rnn_trial:0, iter:11899/20000 loss:1.6946529138088227
# generated sequence: Waick never calleked we has
#      some
#      ram, rresthedsing beforing had been juries stour. Bether!
#
#
# rnn_trial:0, iter:11999/20000 loss:1.653759104013443
# generated sequence: Whilr heally onetoicus could, master arraps surmis the vispow. I was woter to obedted in the time hav
#
# rnn_trial:0, iter:12099/20000 loss:1.6818299567699433
# generated sequence: We
#      which my on I shissian by I
#      ily plainet with and I
#      firm."
#
#      ""Tushortced manig
#
# rnn_trial:0, iter:12199/20000 loss:1.6836278164386749
# generated sequence: Whave as I have.  My swill a secused frome and no me have undable who they lay offer. "Yellen, or ied
#
# rnn_trial:0, iter:12299/20000 loss:1.721422574520111
# generated sequence: Whet wit?"
#
#      He oft of eyess into a cacring and we to you was could to dister wubrond, these coun
#
# rnn_trial:0, iter:12399/20000 loss:1.6757707464694978
# generated sequence: When he doch were of just that yeire in one thouphoser," I am that I say in the Ilmest it, on aboum v
#
# rnn_trial:0, iter:12499/20000 loss:1.6735908997058868
# generated sequence: We tood arawure stilmanger fool So probay ond sick sith in down am peishigh to
#      louglechuritay."
#
#
# rnn_trial:0, iter:12599/20000 loss:1.6821787977218627
# generated sequence: What meth lighth overy defolmes lathtelleds down the
#      niss: On the elfight have at thoughan was f
#
# rnn_trial:0, iter:12699/20000 loss:1.728989999294281
# generated sequence: When it."
#
#      "'There walkans, Engloptwan mutesell
#  I can thim have
#      tellan-'E
#  le Patented,
#
#
# rnn_trial:0, iter:12799/20000 loss:1.7269133162498473
# generated sequence: We raust lang, and in tere vuan we haspanion out, he him harne patfial
#      surpestle-he whire to
#
#
# rnn_trial:0, iter:12899/20000 loss:1.6958699011802674
# generated sequence: Whlled to his cring-her. Mo."
#
#      "Don Upesore."
#
#      "Dunted upon I feck took of to mes, and
#
#
# rnn_trial:0, iter:12999/20000 loss:1.6916250777244568
# generated sequence: Who were was you subjeanterplion, he had not I hardeal up as ray. He of ohe have seemans stishents th
#
# rnn_trial:0, iter:13099/20000 loss:1.6981310892105101
# generated sequence: Who e"tion! Araipe a dittice."
#
#      "One, thought and am Brval?"
#
#      "You the Bangginel tell and l
#
# rnn_trial:0, iter:13199/20000 loss:1.7147573637962341
# generated sequence: Which froplus
#      we is and he had cloiressactment. Dakefcerdagly lodgence held if incor
#      dregge
#
# rnn_trial:0, iter:13299/20000 loss:1.6935518705844879
# generated sequence: Wheles,"1
#
#      "Withress.  That?"
#
#      "A way. "No, it?" CHold we necorder be was and been with For
#
# rnn_trial:0, iter:13399/20000 loss:1.688140263557434
# generated sequence: Ward which houle thin well shomaniouter
#      swringed scaves, abreed. It'weather than and line, bupit
#
# rnn_trial:0, iter:13499/20000 loss:1.7027529048919678
# generated sequence: Whres
#      sibe an ehplopt me, I sat the fely beavilye had tur arrearing in Lashly, her usholl,
#
#
# rnn_trial:0, iter:13599/20000 loss:1.6671679735183715
# generated sequence: Whell upan to Miever to that eapcruld," said he.
#
#      ""The lotols." he sloss my losting
#      lougl
#
# rnn_trial:0, iter:13699/20000 loss:1.6912561309337617
# generated sequence: Wite? Sitever Watt my camm forcar's
#      "Eake."
#
#      "Nor a rido mind that aty chopppentess weight,
#
# rnn_trial:0, iter:13799/20000 loss:1.6753576517105102
# generated sequence: Whove man dripping promes. I
#      her replans will Wattine at his erss is none see which he. puthing.
#
# rnn_trial:0, iter:13899/20000 loss:1.6627040350437163
# generated sequence: Whllm, gevingn to as wayt we sundy.  but he is best furting muchridny him
#      that the
#      lacly th
#
# rnn_trial:0, iter:13999/20000 loss:1.6932203125953675
# generated sequence: Wirt ong a bodserpebber fargimidon the camded his
#      que was had that saip-a bitid, and his assity
#
# rnn_trial:0, iter:14099/20000 loss:1.6526803076267242
# generated sequence: Welest, by we was
#      backecter this upon my wincouse you sound of the did betpee. I throum. I the r
# rnn_trial:0, iter:14199/20000 loss:1.687364830970764
# generated sequence: When a
#      may the man's it house of hark upon a withere whet he shaling which sox pust as As a fine
#
# rnn_trial:0, iter:14299/20000 loss:1.6754455864429474
# generated sequence: When? "No but has not a crocGo Sback my drove has lacguzing surdore nest he amelides bry my couth vol
#
# rnn_trial:0, iter:14399/20000 loss:1.6663848316669465
# generated sequence: Whuce age shourned.
#
#      "It had the beid is wet bigiath he have fird even this eetace. I
#      one r
#
# rnn_trial:0, iter:14499/20000 loss:1.7074894905090332
# generated sequence: Where an an and a herd of reptaid,
#      to Ton't one dut pook the face
#      that my terlow.
#
#      "As
#
# rnn_trial:0, iter:14599/20000 loss:1.6652849686145783
# generated sequence: Waut all was take in me not when for Tap or the laght. "Yall
#      clomed threp why me cigmed into his
#
# rnn_trial:0, iter:14699/20000 loss:1.6799028968811036
# generated sequence: Will out feartives it. Aherow of his wit knecting a packed ops of it wese
#      his sinquive nothing m
#
# rnn_trial:0, iter:14799/20000 loss:1.7225688588619232
# generated sequence: When thaure that ablang made a shaning for the sale as bef my counder. If whe
#      uson his frubs the
#
# rnn_trial:0, iter:14899/20000 loss:1.6559729087352753
# generated sequence: Willing a lay wed her went-reprutton, horre't atn where so to comwire have, and she his
#      winled a
#
# rnn_trial:0, iter:14999/20000 loss:1.6515073335170747
# generated sequence: When time
#      jurgered murden.' Holmes,
#      got'se
#      in maation, and be very extre of the hisged
#
# rnn_trial:0, iter:15099/20000 loss:1.6897061169147491
# generated sequence: Wht
#      gonny. There worrist?' I she looke to which I hung night,
#      three have I was an of youm t
#
# rnn_trial:0, iter:15199/20000 loss:1.6763894712924958
# generated sequence: Whise with had as but I wheriblunner. In oncrom, with of
#      puzor of sown, drothe," snather
#      mi
#
# rnn_trial:0, iter:15299/20000 loss:1.6702887690067292
# generated sequence: When bitnly we expeem on the Caiter prase with one hank, had down. I had seepurdure repge de. "But on
#
# rnn_trial:0, iter:15399/20000 loss:1.6940431189537049
# generated sequence: Whom aster what exnearurre with,
#      Hormoliebeat murty house manion the
#      mhan I huidery mindou.
#
# rnn_trial:0, iter:15499/20000 loss:1.6698778820037843
# generated sequence: Whisk on There
#      one durins in book was donize old not
#      which whece spittion," she
#      retore
#
# rnn_trial:0, iter:15599/20000 loss:1.6944029808044434
# generated sequence: We has strises heaal upint,""
#
#      "Bood shall precked as darn
#      pospeng
#      cossistsened swor,
#
# rnn_trial:0, iter:15699/20000 loss:1.638928530216217
# generated sequence: We handir got the
#      clew the oncerlenn with frietur before to the Enging nothisted in there artid
#
# rnn_trial:0, iter:15799/20000 loss:1.675011545419693
# generated sequence: Wake skit of the suckee it denor have
#      should becer turnot. Donile. DTher or at listettidar
#
#
# rnn_trial:0, iter:15899/20000 loss:1.6821145415306091
# generated sequence: Whilp was back Dongathening Dossed abraty. No. I heagnighE'"
#
#      "You has not dif. "Wirs of alded a
#
# rnn_trial:0, iter:15999/20000 loss:1.6966466546058654
# generated sequence: When I have my bean.
#
#      It liathisher
#      you
#      shenlissent
#      bitibions so listive on the h
#
# rnn_trial:0, iter:16099/20000 loss:1.689687420129776
# generated sequence: Whin sank one, thisprusk swill us at to binet, not abous, was that I drage purn that one becom."
#
#
#
# rnn_trial:0, iter:16199/20000 loss:1.6802240896224976
# generated sequence: With was. We out bytapers, stace, and
#      bas
#      adyopely alarestere to set bro
#      to simes Peat
#
# rnn_trial:0, iter:16299/20000 loss:1.692804319858551
# generated sequence: While Morstion is wall befors is sulpesst peokerts I at each of the diffawe
#      will. Icrur oved for
#
# rnn_trial:0, iter:16399/20000 loss:1.6670288288593291
# generated sequence: We reldy of interved, then the tobttalase?"
#
#      "Wleok you comot so face now you moment of crair,"
#
# rnn_trial:0, iter:16499/20000 loss:1.6673646295070648
# generated sequence: When a foner?"
#
#      "'I was a seatie."
#
#      "I at as I can nuthing a foscioged."
#
#      "Gearn, and
#
# rnn_trial:0, iter:16599/20000 loss:1.6548879396915437
# generated sequence: When in that
#      leard."
#
#      "Wears sut thas
#      from nempleally bhon a man I have in that that h
#
# rnn_trial:0, iter:16699/20000 loss:1.6695404469966888
# generated sequence: Wher our sprodnan metelmous
#      drected heich upon a signelve when hirie ous would heare and that us
#
# rnn_trial:0, iter:16799/20000 loss:1.6758254981040954
# generated sequence: Where hands a coin', Masuliop kefory, you roundeneft I am would glaad, "The thuld had from Sounds, wa
#
# rnn_trial:0, iter:16899/20000 loss:1.650822103023529
# generated sequence: With to he head,' sat at the bould I came. And nextary for a vipopsonig us sole
#      which coal I sus
#
# rnn_trial:0, iter:16999/20000 loss:1.655874593257904
# generated sequence: When weak
#      takented as
#      I have how was awfair room, and be him notel, stroar. I have seat the
#
# rnn_trial:0, iter:17099/20000 loss:1.6954856967926026
# generated sequence: We he wey not the moor W0wey happrong men will was takf."00
#      I had asturns.
#
#      "Joge my
#      o
#
# rnn_trial:0, iter:17199/20000 loss:1.6593515181541443
# generated sequence: Whedpionden remarraw, got was thadwion was what is with thinsica
#      all your the queds knaching cha
#
# rnn_trial:0, iter:17299/20000 loss:1.6346937370300294
# generated sequence: We awite so leave in him.
#      The very one of Prowesh upon prisives, and the asscages. "I hrerts in
#
# rnn_trial:0, iter:17399/20000 loss:1.704805200099945
# generated sequence: Wisker upon that a smow, I can upous relates I here surmaly.  It as squis.
#
#      "Yes, I day that you
#
# rnn_trial:0, iter:17499/20000 loss:1.6590886509418488
# generated sequence: While with my was stress it?ms agaioge--or to
#      with, I keat not so formactaw on stone of me od ve
#
# rnn_trial:0, iter:17599/20000 loss:1.711010946035385
# generated sequence: Who the long rose in to me."
#
#      "F s hound accironr sody.
#      Lesgattires, shall of frombed a sla
#
# rnn_trial:0, iter:17699/20000 loss:1.7130902075767518
# generated sequence: We thime for Leawt.
#
#      The rirentainife, see over a work there Tratidertairey, askiny omvery
#
#
# rnn_trial:0, iter:17799/20000 loss:1.6627349543571472
# generated sequence: Wh, a
#      like nets hes, war to news mentrerd
#      fines faice frica.
#
#      "You."
#
#      I had friti
#
# rnn_trial:0, iter:17899/20000 loss:1.6527592706680299
# generated sequence: Who
#       Mr. Buttert's from see to
#      sod, and I chird his so converfellice-to deal that I stlocke
#
# rnn_trial:0, iter:17999/20000 loss:1.6690109527111054
# generated sequence: Weter yeerst. Of there a
#      good Moster frow it, I pot riry this seqon wind noth,
#      to be
#      r
#
# rnn_trial:0, iter:18099/20000 loss:1.679108110666275
# generated sequence: Winday my call in turree we mut, but his prossent said houter to two pracan peativen fitoly
#      own
#
# rnn_trial:0, iter:18199/20000 loss:1.6634090793132783
# generated sequence: Watkery in figrriit pan'w sto fieLely where is might eyft we can ond seet thare try's that I betion t
#
# rnn_trial:0, iter:18299/20000 loss:1.6569070959091186
# generated sequence: Who naskmenws alls have of the let and when how Bly lell take once, cos and her which which the blown
#
# rnn_trial:0, iter:18399/20000 loss:1.6642136335372926
# generated sequence: What exacrister the lides. For his contuch him dleaval soned me
#      in caupponing eegle can way it i
#
# rnn_trial:0, iter:18499/20000 loss:1.6510446226596833
# generated sequence: We had sight one sil that he her Mol I seath she the so to is upon
#      ftat the meat I was of the wh
#
# rnn_trial:0, iter:18599/20000 loss:1.6817115640640259
# generated sequence: Wheamen Frhem the gelils have bery of the det memberem his scrassed upen my popiar that I knemest tho
#
# rnn_trial:0, iter:18699/20000 loss:1.6530051624774933
# generated sequence: Weet fliiping own, sir, and I bank in her how evening in a diskies, can
#      stire of Dr. Welens in s
#
# rnn_trial:0, iter:18799/20000 loss:1.638584678173065
# generated sequence: Which with the rosde: Sirse.
#      I exiting a night is yo In thor you
#      stibenase trath of Squiste
# rnn_trial:0, iter:18899/20000 loss:1.6597157001495362
# generated sequence: Whom had liot that that about lown that wive hom, by anieted reared
#      indost had dry would leod re
#
# rnn_trial:0, iter:18999/20000 loss:1.6529005253314972
# generated sequence: Whimen your unalling allingh the obelon; which a head have -bespanaco an he. You have not on he in ha
#
# rnn_trial:0, iter:19099/20000 loss:1.699934459924698
# generated sequence: What the exsmunn to Dresuries. The day rath and RoNar
#      here in the docc? remo say, We bie are I l
#
# rnn_trial:0, iter:19199/20000 loss:1.695000547170639
# generated sequence: Wisly in so fon't his addease moorer most known frater in street whened Longer-way harmentable. His
#
#
# rnn_trial:0, iter:19299/20000 loss:1.6857666492462158
# generated sequence: Wnow sengey your hells,
#      had
#      mitemerst these assed on were Mr. Holmes. I' Waysency, but in h
#
# rnn_trial:0, iter:19399/20000 loss:1.6579219388961792
# generated sequence: Werbededs all
#      entap sodeen, a desponde tound appo
#      exert
#      prasp yeasped in poon were is
#
# rnn_trial:0, iter:19499/20000 loss:1.6620067608356477
# generated sequence: We rere with some would parenes. There finer. The reave mpather an instracever twasers."
#
#      "Mus i
#
# rnn_trial:0, iter:19599/20000 loss:1.6710769307613373
# generated sequence: With dears of was in
#      led expe, mine finneh was a for stean rigns all
#  sings, be in beot for the
#
# rnn_trial:0, iter:19699/20000 loss:1.683550956249237
# generated sequence: Wingh the tromby more
#      stored half fads. "Examine was beoosenced sholl,"
#
#      "We shookely sto y
#
# rnn_trial:0, iter:19799/20000 loss:1.6895324313640594
# generated sequence: Witthe his
#      can wite, croval mity
#      quade that from he herleos, and him od!" I am plearor safe
#
# rnn_trial:0, iter:19899/20000 loss:1.6698242783546449
# generated sequence: Wisk for my signed terled ave conSthat me of of us is fell of Brifs the berlore. It in the dood ussim
#
# rnn_trial:0, iter:19999/20000 loss:1.6418265080451966
# generated sequence: Well, I droade, way am extembon, a
#    d of the Morcinge end neecdlees backed his have the oury, but h
#
# rnn_trial:1, iter:99/20000 loss:3.02132269859314
# generated sequence: Wc oae poatf kas  oaghe  aecle    o ovgue d"har oatttr e r s da  end  t licsoam iltwn  le  astmstetat
#
# rnn_trial:1, iter:199/20000 loss:2.6600257563591003
# generated sequence: W te larink be wvrd  fsaav r wrytaat n my ca glcledosbpdtnion woore teoc''aroipd theheasy oouy
#  t"al
#
# rnn_trial:1, iter:299/20000 loss:2.390765311717987
# generated sequence: Wp has the toulle sP ded the B send yre salud sede them
#
#      fee the  hor coe se an
#
#        hange
#
# rnn_trial:1, iter:399/20000 loss:2.2937421202659607
# generated sequence: W, ut. I rom al be un ag hing souge hantin junt got niss In hy it hecer inteed wafres a9 I thisd the
#
# rnn_trial:1, iter:499/20000 loss:2.2149653208255766
# generated sequence: We corecn to medseget way thit dotile rooigh mas tharengd be hon prothomd heroid
#   f he the I on to c
#
# rnn_trial:1, iter:599/20000 loss:2.137958778142929
# generated sequence: Wu leoly athels." Vo loukinelyor tonked poon eur ho momload thicitou.
#
#     waHk!."
#
#     "atakr foat.
#
# rnn_trial:1, iter:699/20000 loss:2.155472127199173
# generated sequence: Whe-this t'Ther, whar thingich fottimund any, que,"
#
#  m et lerladebn, purd. "Yhadbe-lede rore Werll-c
#
# rnn_trial:1, iter:799/20000 loss:2.1010591888427737
# generated sequence: Whith th the flast-  s hrory hoome ha bus.'
#      "I."
#
#      "Hesund  umCseecrrnt he weenetr, I youme
#
#
# rnn_trial:1, iter:899/20000 loss:2.1026376700401306
# generated sequence: We the mics belkt and het and ory co le. Ddet my thJt ston s
#      hlisr to mey heare Ralcith. Gvesey,
#
# rnn_trial:1, iter:999/20000 loss:2.0492528140544892
# generated sequence: We thes with the coudre, ande sookedse.'
#
#
#      matof ucthis angr ttely of fillnet?
#
#      "Oxpize
#
# rnn_trial:1, iter:1099/20000 loss:1.9893333554267882
# generated sequence: Weriic acund the wad it, warn you evobe-vo then to the s'Dust aSrey qulStot ougear
#      y m cole thet
#
# rnn_trial:1, iter:1199/20000 loss:1.9989371371269227
# generated sequence: Wher,""
#      a cime-sevee uid. Suslaidry a courd. Thimm door arl-s
#      wigrierthed stomeps
#      aPli
#
# rnn_trial:1, iter:1299/20000 loss:1.9543972826004028
# generated sequence: We of nit in the vere sie foun shor aik afle to me, wheve wor
#      ie, ;in enne seaes was I a sentrut
#
# rnn_trial:1, iter:1399/20000 loss:1.959953602552414
# generated sequence: We I aplessime. LriZit no crat blaiks stitse nlitur mith I  Wert umunt and ssamw Of that aple."
#
#
# rnn_trial:1, iter:1499/20000 loss:1.9520912384986877
# generated sequence: We is doed,
#      avarm wave, shis and herwrtht we had
#      conditsant cand whald, this can, wes sorpe
#
# rnn_trial:1, iter:1599/20000 loss:1.924502114057541
# generated sequence: Wan'tuld-en the caideple by of blibe, shan has andred that than dectians but quirgeangeinod, wand in
#
# rnn_trial:1, iter:1699/20000 loss:1.9143971264362336
# generated sequence: We was as him ef sutter and san coo in the suipeslagy. Whit, as have
#      anse
#      lo mes sJarp and
#
# rnn_trial:1, iter:1799/20000 loss:1.9211686253547668
# generated sequence: Wist was selptas con tsene am abe. Ien and bren cay
#      Bno unow sonclat he san a sused and wourd a
#
# rnn_trial:1, iter:1899/20000 loss:1.9211022818088532
# generated sequence: Wero
#     ters, at the hostakn of the your
#     tothed a
#      you shang. I theringer ows apting wandes;
#
# rnn_trial:1, iter:1999/20000 loss:1.8551082742214202
# generated sequence: Wese out grems and sougisese-ce the reall,
#      grooct bo for ourn whil so feroagard of oped
#      ge
#
# rnn_trial:1, iter:2099/20000 loss:1.8910662937164306
# generated sequence: We of wercanged sase beclost of momaming wo kmy byen but Mixy it inpo," yout thitt. Rout to fied ofok
#
# rnn_trial:1, iter:2199/20000 loss:1.8396542966365814
# generated sequence: Werep Misapspor I thoup of that is aice beatice ofing, Mictoonshy but at of inde o the cacl to is
#
#
# rnn_trial:1, iter:2299/20000 loss:1.8685501408576966
# generated sequence: We thonthont in bons lagbedatice bavime found cick, that ha donk asar. Wersand winck the onite I wigh
#
# rnn_trial:1, iter:2399/20000 loss:1.8616526412963867
# generated sequence: We has bepigiict.
#
#      "No ressicued I Pooks, Lope fors, by Dy. Ne tongely ond that his upove gefthe
#
# rnn_trial:1, iter:2499/20000 loss:1.8468113827705384
# generated sequence: Wald?"
#
#      "He as what I mooked atarl and noone and he tremh face to morr he
#      and has pomestor
#
# rnn_trial:1, iter:2599/20000 loss:1.8737850546836854
# generated sequence: We Gosfis aly my bxtirher."
#
#
#      This wolden came of Ed if whis nor ight dust.
#
#      "Exa her sowa
#
# rnn_trial:1, iter:2699/20000 loss:1.8607060396671296
# generated sequence: We tantermers, were rayom notinged -way you reamp is in countid trrect upit a nowe it it a moreed tra
#
# rnn_trial:1, iter:2799/20000 loss:1.8834024035930634
# generated sequence: We and thele with higpostedanove the gro?"
#
#      " y se poter sulay the fariaters. If it a tut.'Yould
#
# rnn_trial:1, iter:2899/20000 loss:1.809387937784195
# generated sequence: We hecexry, fol, quros
#      all, and murly atctive, scouron mee hould are donting a dislent, When on
#
# rnn_trial:1, iter:2999/20000 loss:1.7976481342315673
# generated sequence: We amy sack, Loll, you?"
#
#      "We
#      ol say hism thar your shent sturnel
#      dedisater us noth ag
#
# rnn_trial:1, iter:3099/20000 loss:1.8296861600875856
# generated sequence: Watting itsome on nncighanger byon, Mr. Lorting to ceach-stoniored no
#      coutten the Bore wood resi
#
# rnn_trial:1, iter:3199/20000 loss:1.8553306448459626
# generated sequence: With m monced': the it mo. Which on has
#      in his
#      mring
#      offuctom meatind hor yon, reor ou
#
# rnn_trial:1, iter:3299/20000 loss:1.8503771197795869
# generated sequence: WDriaked paid for
#      his and thisthar arly were ractrank-sountes?"
#
#      "Yo,  Walting, tar thon so
#
# rnn_trial:1, iter:3399/20000 loss:1.8143633437156677
# generated sequence: Well eswipestly shave taked stenteested was
#      abo he.
#      Mrcard the banctsentsint then this
#
#
#
# rnn_trial:1, iter:3499/20000 loss:1.7794298553466796
# generated sequence: Wish his pramed exomsther," he cand and beandsers to his
#  w  e wild qumy-the polleng his masule likes
# rnn_trial:1, iter:3599/20000 loss:1.8016264390945436
# generated sequence: Wething. It is in."
#
#      "In the
#   " "As have wallid way upou had a soedon
#      and leet thit daeded
#
# rnn_trial:1, iter:3699/20000 loss:1.8047762846946716
# generated sequence: We withe us but that ny, "el cracers Strass my fluntimating let, and kenghy," rex-thed erictem pattli
#
# rnn_trial:1, iter:3799/20000 loss:1.8005264723300933
# generated sequence: Wate hear, I saiedsticect
#      it you, which he
#      it is bark nowenteed upst oundenengedvel conchev
#
# rnn_trial:1, iter:3899/20000 loss:1.8361623358726502
# generated sequence: Wenon er. I sith aboutios: diserm. He the oeancent of were this and.
#      "E'shought sor bight creben
#
# rnn_trial:1, iter:3999/20000 loss:1.7921276676654816
# generated sequence: Will clamp uprives. And which a wool
#      veadena?"
#
#      "Yis gair was a
#      over alliting not a sw
#
# rnn_trial:1, iter:4099/20000 loss:1.7905891489982606
# generated sequence: West the man
#      come, any mak; thot for inor
#      whromery thit ghtromned and
#      yow was reads is
#
# rnn_trial:1, iter:4199/20000 loss:1.8222286820411682
# generated sequence: We hes the Suchy have angead out as whigg of seed wroundecimest Strockes,-somtact in to ynow and wele
#
# rnn_trial:1, iter:4299/20000 loss:1.7684936809539795
# generated sequence: Well hou is to hem lang to had
#      sught, thea dethal
#      pextanc- fate
#      show!"
#
#      "'The was
#
# rnn_trial:1, iter:4399/20000 loss:1.7897277510166167
# generated sequence: Well I raiven that hus it in a dengriaked n. I can work rugled. Hident poriee I hang have my cemer -w
#
# rnn_trial:1, iter:4499/20000 loss:1.7685999274253845
# generated sequence: We. Be to bought," jusjest, '8Staitced reed hplm,
#      upretwhing; lifporint?"
#
#      "I wouls surtime
#
# rnn_trial:1, iter:4599/20000 loss:1.7918078243732452
# generated sequence: Well? He sil hand that
#      felpressat onis lived the ligg-sured sak."
#
#      "I hinar allotlver.
#
#
#
# rnn_trial:1, iter:4699/20000 loss:1.7958148610591889
# generated sequence: Whem, this acwousecce, but to there. You ladys ant
#      " hill grienge a curcuss
#      vere from ake i
#
# rnn_trial:1, iter:4799/20000 loss:1.798832530975342
# generated sequence: Wher sChempers,
#      whith undal4 that he she wouldsess his extronting anss is disacted den Mr. She p
#
# rnn_trial:1, iter:4899/20000 loss:1.7685399484634399
# generated sequence: Way linl wand ofte of that morking a vaght him poublensed cowy and alr and stotome and ngadrair," mon
#
# rnn_trial:1, iter:4999/20000 loss:1.7203464496135712
# generated sequence: We the sold-dos some the atling cointy staon," said I have my foot, and the cast? I
#      yous ow the
#
# rnn_trial:1, iter:5099/20000 loss:1.7463904356956481
# generated sequence: Will n masted tokner.
#
#
# rnn_trial:1, iter:5199/20000 loss:1.8146234059333801
# generated sequence: Wo the compen.
#
#      "That lice that I his modons from fortint--mornite him us a gell as the bointise
#
# rnn_trial:1, iter:5299/20000 loss:1.7369977474212646
# generated sequence: Were is was weroes, Yor shads of Jogs. Hat if
#      the shiat Er, forcaaif, than you anof that but of
#
# rnn_trial:1, iter:5399/20000 loss:1.743652811050415
# generated sequence: Where "erongegbley is one and in
#      in, Mustrand, ond seluse he quiete?"
#
#      "Fort the laye to we
#
# rnn_trial:1, iter:5499/20000 loss:1.7409138977527618
# generated sequence: Whe his him gen in me be well yow the within wes as and wousess he sumente.
#
#      "Som, he reipled ho
#
# rnn_trial:1, iter:5599/20000 loss:1.7366379272937775
# generated sequence: Whese mane bictre quihe his
#      to day her ero could, and that out mustagen as or and;" soas anchat
#
# rnn_trial:1, iter:5699/20000 loss:1.7517023658752442
# generated sequence: Wh ten the was a lom halp if Lous you mints an Holfice of the fire theal is
#      No phavane paes war.
#
# rnn_trial:1, iter:5799/20000 loss:1.7324580299854277
# generated sequence: Whot if one grebtiret-know. Theint--spens. It s; and I thaclstard. There and a matf and he. With they
#
# rnn_trial:1, iter:5899/20000 loss:1.775889778137207
# generated sequence: Wh that a lado. And be our said. The sably to
#      pven take for and a peaping yet aftresarted and fo
#
# rnn_trial:1, iter:5999/20000 loss:1.740531153678894
# generated sequence: We coulst of he weatshicice Mr. He has might the mamy has lift to five well, Sumemes
#
#      "I vome ha
#
# rnn_trial:1, iter:6099/20000 loss:1.761035362482071
# generated sequence: Whicrs notched golite of not has rounce Woll
#      has dick half it is the cosmoince going befort all
#
#
# rnn_trial:1, iter:6199/20000 loss:1.7830878627300262
# generated sequence: We werl cass ufatrel we wing. His with the Far of I have laid ford the the said He reficworatisery Hu
#
# rnn_trial:1, iter:6299/20000 loss:1.8151161968708038
# generated sequence: WhPped. "There way puctick compapine overs be through--youghinglapin'--sughetw. I cack. Veary.
#      J
#
# rnn_trial:1, iter:6399/20000 loss:1.7479614698886872
# generated sequence: Whrid hiak his
#      eates and reet, hoamor--knal,
#      elente."
#
#      "Has face chearrag Mr. M3. Chea
#
# rnn_trial:1, iter:6499/20000 loss:1.7382120752334596
# generated sequence: We hand in heich as awnereet oud of Beethey, with it didvibed to the worlick we know of lookis in the
#
# rnn_trial:1, iter:6599/20000 loss:1.7180624830722808
# generated sequence: We
#      facigned the befrocalimer mikemmerasied was othed, so erhelss no was start.
#      thime I's bu
#
# rnn_trial:1, iter:6699/20000 loss:1.7314650225639343
# generated sequence: Whis uptare is
#      it had
#      "Extheraken with stuard know mind was obre you a very book, is make o
#
# rnn_trial:1, iter:6799/20000 loss:1.7511593782901764
# generated sequence: Wxlded Shough scese of "He had sholed and my inss."
#
#      "I mresiented into that sel shadencled sllo
#
# rnn_trial:1, iter:6899/20000 loss:1.7306228530406953
# generated sequence: We cladfour a kipe of Loud aus in at of he the gres beet routed been meed you go do Cary, when this r
#
# rnn_trial:1, iter:6999/20000 loss:1.6946484649181366
# generated sequence: With would thoughtsprathed for fol appoased My
#      brong in paper whose  I sey unasces upol ste. Wh
#
# rnn_trial:1, iter:7099/20000 loss:1.7098657500743866
# generated sequence: We the on he madat-that homcknceicase on shand pinita--an that aystinlid
#      Mrsardion a ony to beof
#
# rnn_trial:1, iter:7199/20000 loss:1.7074617457389831
# generated sequence: Wissey," setions?"
#
#      Thear what to learce fore. He is whiched was said howeve which Holars fitely
#
# rnn_trial:1, iter:7299/20000 loss:1.7516484129428864
# generated sequence: We can hascwine. There in"
#
# ...
#
#      "Only, to a tordeded the Nearking tule It prope, as arr his take tray
#
# rnn_trial:2, iter:11099/20000 loss:1.6975813138484954
# generated sequence: West my dow, and sin that cuscess, I heard on the
#      sas withissibly.
#
#      "Is, but muckquenes. My
#
# rnn_trial:2, iter:11199/20000 loss:1.7095966601371766
# generated sequence: Watet by benair it where deed to as my awain. I we can in?t
#
#
#      "Leads we face it is geveesite sol
#
# rnn_trial:2, iter:11299/20000 loss:1.6943378508090974
# generated sequence: When I amed of your
#      told him to rubneme?"
#
#      "The holt been ever.
#
#      "An
#      valt, than a
#
# rnn_trial:2, iter:11399/20000 loss:1.6645030117034911
# generated sequence: Whis
#      groud and not inden for
#      fivence of farty what it in the
#      was apxcoss of
#      weie?
#
# rnn_trial:2, iter:11499/20000 loss:1.6884152626991271
# generated sequence: Whis his peicuded to so stood that my switour
#  dreaute your.,"Mut uldowired one he.  that he
#      I h
#
# rnn_trial:2, iter:11599/20000 loss:1.6892667722702026
# generated sequence: Wh.   draster Houndre his wast for ender in you ccorterinc. If have appunned. Alst of foMte has unter
#
# rnn_trial:2, iter:11699/20000 loss:1.7028054904937744
# generated sequence: Why brought to mind oun, and be the sissurstly of go cially of his for may-ladion a may is Holmes in
# rnn_trial:2, iter:11799/20000 loss:1.692348189353943
# generated sequence: We have in there the
#      as a matt our dood yourimiome in a croniirile?"Well amperpermeded."
#
#      "
#
# rnn_trial:2, iter:11899/20000 loss:1.6866913378238677
# generated sequence: Wearefferel throughm--Many, more, "
#
#      "Well of to a mighy come ohf of arracked-bett you dead so,
#
# rnn_trial:2, iter:11999/20000 loss:1.6634510099887847
# generated sequence: When foother all rerconoum
#      rematson of him for a drieght faceles and note it of siraght ove not;
#
# rnn_trial:2, iter:12099/20000 loss:1.7317344093322753
# generated sequence: We which monseam of ready inshent, and hir, surburt. A
#      bevalleshann highfubigh the retilams.
#
#
#
# rnn_trial:2, iter:12199/20000 loss:1.6848202669620513
# generated sequence: Wating must "Ohe oun spere that the budgey there noumined you afte they stry name have in fictope Me,
#
# rnn_trial:2, iter:12299/20000 loss:1.766021956205368
# generated sequence: What in the tall with was
#      plalf down'ch formed."
#
#      "You I care mind waich that you and langi
#
# rnn_trial:2, iter:12399/20000 loss:1.6968819582462311
# generated sequence: Watmor be,  lenger, all mustle sicle sugghe into eyen
#      of he hoh that chenides, cneeled which whe
#
# rnn_trial:2, iter:12499/20000 loss:1.6834492814540862
# generated sequence: Whle subjeat a wime be musiding anyened the hold. Accabwaininged as this down that tive was wound ove
#
# rnn_trial:2, iter:12599/20000 loss:1.6979414522647858
# generated sequence: Wers in smal, am
#      gonsening he had appeaneled reather.
#
#      "Frank of Lestibenced?"
#
#      "We ma
#
# rnn_trial:2, iter:12699/20000 loss:1.7106095945835114
# generated sequence: Whet folly," said Holmes when.
#      Hus was, and who everyode of we come somer one Bave
#      it. Holg
#
# rnn_trial:2, iter:12799/20000 loss:1.7258077335357667
# generated sequence: What at nevinwhercest them
#      which! out oqMy let I dishar in a thote
#      hive them,
#      Kines th
#
# rnn_trial:2, iter:12899/20000 loss:1.663245862722397
# generated sequence: Whickiciatiot and go tiet, busilar, and been andialted a claving, felm and not comman to to the same
#
# rnn_trial:2, iter:12999/20000 loss:1.6925997006893159
# generated sequence: We, I can the gain taked the leglied nobshers if got? Afters is shall and that I amse. There surd sus
#
# rnn_trial:2, iter:13099/20000 loss:1.6711730301380157
# generated sequence: We cased. But hear it, and statitydet! "goart a praceentyst
# .
#
#
#
#      "I
#      throgghingerealy in a w
#
# rnn_trial:2, iter:13199/20000 loss:1.7014696049690246
# generated sequence: Weisht, ansy so yet
#      lining to Celved.
#
#      "You know old
#      otherbly anstselver, his with
#
#
# rnn_trial:2, iter:13299/20000 loss:1.6704136776924132
# generated sequence: Whishing. "Ye; Dr! How flest by which Must-on the face ushopping on the hands that a stretratud tin t
#
# rnn_trial:2, iter:13399/20000 loss:1.7117332875728608
# generated sequence: We compo. CHist. What throw oning when he me
#      which of an oun in excheus arsw, an is a doors Helu
#
# rnn_trial:2, iter:13499/20000 loss:1.6908835780620575
# generated sequence: Wear stift. That whathy in a by that has of
#      hum inquired at othad out Massimed. And one not it a
#
# rnn_trial:2, iter:13599/20000 loss:1.6940828478336334
# generated sequence: Way."
#
#      "'Do thing day not of the
#      the tast dentidest that the twentwonderd you now near and
#
#
# rnn_trial:2, iter:13699/20000 loss:1.6804693746566772
# generated sequence: Weld and-stand o canspion. The calgeatived dradn spep his come that whicted as a sutterbupies sare ab
#
# rnn_trial:2, iter:13799/20000 loss:1.6564777636528014
# generated sequence: Well, it with the adion, on of wenching oched dis ond Murs of has shone out of tuim, invelding of som
#
# rnn_trial:2, iter:13899/20000 loss:1.7246137356758118
# generated sequence: Well, of it unCerms and yet.      it
#      took of direct.
#      Whichth reclice of and to placeds, and
#
# rnn_trial:2, iter:13999/20000 loss:1.684369249343872
# generated sequence: Well manssed am that the Bling all
#      Missilfencolys. Which of seppies. But Mos spurs howeven.'
#
#
#
# rnn_trial:2, iter:14099/20000 loss:1.6716181063652038
# generated sequence: We'sty rodmerfor
#      for rod, and lackly a coart papset, throk. The famed of the chatted the ward wi
#
# rnn_trial:2, iter:14199/20000 loss:1.6868619239330291
# generated sequence: Whod that they abokitate he counting--then that the rarrenthontureved us that. "Onlow was not withing
#
# rnn_trial:2, iter:14299/20000 loss:1.6802052903175353
# generated sequence: Watly room."
#
#      "Nows.
#
#      "Wat is me a pelping."
#
#      "You we chacking there was it compank tw
#
# rnn_trial:2, iter:14399/20000 loss:1.6812949240207673
# generated sequence: Wexmpances he had butter.
#
#      Attees, stare as acman it," had, and up what we am sime we with the u
#
# rnn_trial:2, iter:14499/20000 loss:1.6765922379493714
# generated sequence: Wey,
#      handly, way, the cathers into a
#      arnestaoned and any he way almay. The ronolies, your t
#
# rnn_trial:2, iter:14599/20000 loss:1.684673467874527
# generated sequence: Water has lifter
#      stame ofe were by the spashemiant mursion wand upon Some in the mortee, as
#
#
# rnn_trial:2, iter:14699/20000 loss:1.6904360818862916
# generated sequence: What it. "My. The. Oclant, but no a theem a forgrawn Mas, for Bornes.'
#
#      "He had hand trame
#
#
# rnn_trial:2, iter:14799/20000 loss:1.690135074853897
# generated sequence: Weld yegmaniea Noader I hacdsely beave tent to uctEy--tandore's to Forned and nothing revildly after
#
# rnn_trial:2, iter:14899/20000 loss:1.6496209144592284
# generated sequence: Welly quise under. I excead ingraight.
#
#      "Shemation
#      hy facin founs your soched, prourdored t
#
# rnn_trial:2, iter:14999/20000 loss:1.6758908200263978
# generated sequence: Well, Lut I way?"
#
#      "In the man him, send his rowe mortertip his hamGer with a courspling to me f
#
# rnn_trial:2, iter:15099/20000 loss:1.654377862215042
# generated sequence: Wels to were boinicion, Irashed had been hell me," he
#      rider are
#      walks hather
#      caidlly-l
#
# rnn_trial:2, iter:15199/20000 loss:1.7180540108680724
# generated sequence: We very saculy so, and the evody do yer street of beferee. "I have Barred it caces toom, and and june
#
# rnn_trial:2, iter:15299/20000 loss:1.6724485838413239
# generated sequence: Wested; some just.
#      The hand conctared frol lestioester, you to blook that the have see hand over
#
# rnn_trial:2, iter:15399/20000 loss:1.6661044919490815
# generated sequence: Why the quier and a harned, are, arreef-over in yemor was is fave at
#      coblectrear man catcher Hol
#
# rnn_trial:2, iter:15499/20000 loss:1.6792786192893983
# generated sequence: Well upen that I hers mefferter?" hoinst than a matt-. I thirk. If carfen,
#      in anartizeing, I stu
#
# rnn_trial:2, iter:15599/20000 loss:1.6928980934619904
# generated sequence: Well, sterper than that what with opionity had glake,
#      it. How from hirsptable, that who was, no
#
# rnn_trial:2, iter:15699/20000 loss:1.683710867166519
# generated sequence: Well mo to gloned at my from he would the firy fiots. ERiever upon two alseasoives elay fatestoled 34
#
# rnn_trial:2, iter:15799/20000 loss:1.7031204426288604
# generated sequence: Whis"ing lakgulw yet is once with the therouroad relier. Iving would her siving throw the mome the th
#
# rnn_trial:2, iter:15899/20000 loss:1.6915950226783751
# generated sequence: Welllying felly of Mr. Wellow
#      who throg's gronge a some is and he sartt was atten in heard to be
#
# rnn_trial:2, iter:15999/20000 loss:1.6788372695446014
# generated sequence: Well prepented beg he revpletsleet
#      the lottle, but, to papind up, and, Mr. Scaped had be by orum
#
# rnn_trial:2, iter:16099/20000 loss:1.6999277317523955
# generated sequence: Well stiance the exach. "I hand
#      suppos's been who wibl older
#      pross, what his
#      copfory
#
#
# rnn_trial:2, iter:16199/20000 loss:1.673745344877243
# generated sequence: Watsy nisted.
#      The meut at there hour. He peppernery upon I deelered thoresalsiw."
#
#      Itt his
#
# rnn_trial:2, iter:16299/20000 loss:1.6442357230186462
# generated sequence: Weyt could that I was the knost cathed to keer
#      they
#      Sat the Denturabable now upen and with
#
# rnn_trial:2, iter:16399/20000 loss:1.647356014251709
# generated sequence: Wollow.                 " He was
#      stants is that he to mind upon the conken we shirges dir ttibge
# rnn_trial:2, iter:16499/20000 loss:1.7036748790740968
# generated sequence: Well our wher forrest the beady."
#
#      "I lack a dal'ly which no wipe verwave I reaking myar all, Wa
#
# rnn_trial:2, iter:16599/20000 loss:1.728957223892212
# generated sequence: When then the brick or I hith, comnive to in the conce and perchere man will berd inquitent had eshor
#
# rnn_trial:2, iter:16699/20000 loss:1.6757785713672637
# generated sequence: Witninews to be really," Said of tillow, Stand.
#
#      "Be of the what he, by you to dighing, fire Gin
#
# rnn_trial:2, iter:16799/20000 loss:1.6734646320343018
# generated sequence: Watgry Wam some the are servered."
#
#      To were of termact. THa
#      had not you see fours o'le year
#
# rnn_trial:2, iter:16899/20000 loss:1.6421398723125458
# generated sequence: Whese with moent.
#       "Hatite the resparnce the arished intay that susmed rached could so'ne the hu
#
# rnn_trial:2, iter:16999/20000 loss:1.6689657187461853
# generated sequence: Wello's
#      through and why tragar-would no rach I
#      the boonazing any I eary questers, and moon,
#
# rnn_trial:2, iter:17099/20000 loss:1.6678917956352235
# generated sequence: Well you colm he would so amoughincen.
#
#
#                     "Sheman untriage
#      fart me
#      gay
#
# rnn_trial:2, iter:17199/20000 loss:1.691137534379959
# generated sequence: Watreyponer poodon aechised and heart the nevely exceatab, and I.  It I at the
#      there is youry nu
#
# rnn_trial:2, iter:17299/20000 loss:1.933059148788452
# generated sequence: Whemsorion and chitsed, youst pEzhs thought
#      firchrory whr
#      take sucd that youggate alimy in
#
#
# rnn_trial:2, iter:17399/20000 loss:1.791880909204483
# generated sequence: What which on lookd and toldef-knural clarm of hid windsy over reated idure. Scee
#      raloright. I a
#
# rnn_trial:2, iter:17499/20000 loss:1.7507924056053161
# generated sequence: Was your did
#      Bast spartarroyorsed to det he frre. That rendor Row apen face to-day it him ank I
#
# rnn_trial:2, iter:17599/20000 loss:1.721890617609024
# generated sequence: Welr He ladys in her
#      so sprealy someing rodmame, hus in spek the reaccrosd."
#
#          The coull
#
# rnn_trial:2, iter:17699/20000 loss:1.6963151252269746
# generated sequence: Whye in fry who come compisers for the owned healon, way us. There and three to anromply and for shan
#
# rnn_trial:2, iter:17799/20000 loss:1.6808124697208404
# generated sequence: Well, the nuge in secilment)mensous your is freest coumsenty, I good and then one
#      to led pothung
#
# rnn_trial:2, iter:17899/20000 loss:1.7107252621650695
# generated sequence: Well, trace be qainh wishoty minder?' he
#      down hintantocem it firquid be when hew you had his wif
#
# rnn_trial:2, iter:17999/20000 loss:1.714874427318573
# generated sequence: We hear been my riciniced however epsean ifed this have I suant symatcions
#      pound the strong lews
#
# rnn_trial:2, iter:18099/20000 loss:1.705479245185852
# generated sequence: Well, call!  she graund in then high how Bock it the put crovgiorhouselictionOd draugh, did of which
#
# rnn_trial:2, iter:18199/20000 loss:1.752097583413124
# generated sequence: Warened leakes from whil, from drey a post
#      I shaw I cratliver
#      Wearth, drend I coClamy-thodd
#
# rnn_trial:2, iter:18299/20000 loss:1.7824793922901154
# generated sequence: Whon't featy aftered crings inhe cook, this Hoass, Yas, and out voubld to acrectitor, or a foot to kn
#
# rnn_trial:2, iter:18399/20000 loss:1.7147047340869903
# generated sequence: Wefand
#      take this for trind doas for the best
#      man window my faddoy sound, for to and any cle
#
# rnn_trial:2, iter:18499/20000 loss:1.6928775262832643
# generated sequence: We prisgepers, Mr. As Mr. Wat the cagars."
#
#      "The manborurcark alazed facer
#      a
#      with had
#
# rnn_trial:2, iter:18599/20000 loss:1.7019119238853455
# generated sequence: When the paber you was steft id the nithamole prentir. "I'ves he. "Truse."
#
#      "I withough sberd cl
#
# rnn_trial:2, iter:18699/20000 loss:1.6636175417900085
# generated sequence: Where."
#
#      "You can wlenden in the lardered that I she had my
#      whochan werce
#      for paider a
#
# rnn_trial:2, iter:18799/20000 loss:1.6813439810276032
# generated sequence: Well, thond Day indicion. I delieved you toble ofe astamaftate the plates."
#
#      "Save to me and for
#
# rnn_trial:2, iter:18899/20000 loss:1.675672597885132
# generated sequence: Whar we
# w      Ganced or the Genn tall, and
#      been, with annece, of can at colles. One was a sprat
#
# rnn_trial:2, iter:18999/20000 loss:1.7055610775947572
# generated sequence: Well, such fomly more only! intrinicabletcidy.
#
#
#
#
#
#
#
#
#       Thos wen your pactirary of overy betoth
#
# rnn_trial:2, iter:19099/20000 loss:1.6712715470790862
# generated sequence: Weast out or a out it seen
#      in exants. But we
# s a greatcripa, myse slear the effacion whith the h
#
# rnn_trial:2, iter:19199/20000 loss:1.6332919120788574
# generated sequence: We servolwere
#      us nother
#      utther oftanwed you look?"
#
#      "The strinte, have answer it hands
#
# rnn_trial:2, iter:19299/20000 loss:1.6989434993267059
# generated sequence: Well in the
#      so. uerfice famselver Strothe wauts's my. The Marnal there, then weard to knith inte
#
# rnn_trial:2, iter:19399/20000 loss:1.6653242552280425
# generated sequence: Well
#      for exrmard the delpow, latiel the
#      toarce you-ruons."
#
#      "Atained in the your toon
#
# rnn_trial:2, iter:19499/20000 loss:1.668309406042099
# generated sequence: Well,'"Well."
#
#      now that foold the 'tcan of
#      my thesh. Warydats,
#      unthonly handsentourder
#
# rnn_trial:2, iter:19599/20000 loss:1.6833087980747223
# generated sequence: When the primbly
#      commant. We was hat
#      dread even that us. I take conno window, but not the A
#
# rnn_trial:2, iter:19699/20000 loss:1.716815184354782
# generated sequence: Wexrock the reves. It is a drenced apfurnur inst, shean at you sat coor alway beear it? A core I amor
#
# rnn_trial:2, iter:19799/20000 loss:1.6767787337303162
# generated sequence: Wham and I way he hat the labene hardens. You croved so orde aried to fight dights asker
#      make."
#
#
# rnn_trial:2, iter:19899/20000 loss:1.6673098802566528
# generated sequence: Whas to esalic lest that the farme be is ond a gress. There your the sorstly to do you his for secruc
#
# rnn_trial:2, iter:19999/20000 loss:1.679729917049408
# generated sequence: Well-been book he a dourd, poom gow' witm if I walkar he woll he and not
#      possiene way the divedo

# %%
all_losses_lstm = np.zeros(int(iters / print_iters))

for i in range(n_trials):
    net_lstm = Net('LSTM')    # Create a new network instance.
    net_lstm.to(device)
    opt_lstm      = torch.optim.Adam(net_lstm.parameters(), lr=0.005)
    loss_func = nn.CrossEntropyLoss()
    losses = np.array([])
    loss_sum = 0
    for j in range(iters):
        input, target = get_input_and_target()            # Fetch input and target.
        input, target = input.to(device), target.to(device) # Move to GPU memory.
        loss      = train_step(net_lstm, opt_lstm, input, target)   # Calculate the loss.
        loss_sum += loss.item()                                  # Accumulate the loss.

        # Print the log.
        if j % print_iters == print_iters - 1:
            print('lstm_trial:{}, iter:{}/{} loss:{}'.format(i, j, iters, loss_sum / print_iters))
            print('generated sequence: {}\n'.format(eval_step(net_lstm)))
              
            # Track the loss.
            losses = np.append(losses, loss_sum / print_iters)
            loss_sum = 0
    all_losses_lstm += losses

mean_losses_lstm = all_losses_lstm / n_trials
# Out:
# lstm_trial:0, iter:99/20000 loss:3.09412109375
# generated sequence: Wara t,rtpfy bbCoinwe
# d tel s. rles u!wriiHyo        re yiento wrddso  a g)chgheh.  akwe hhi a h oarh
#
# lstm_trial:0, iter:199/20000 loss:2.6211491680145262
# generated sequence: W@amgot lnd pias
#
#     N dhouptim dofe iar  in lacred,it  thedl ildveraane
# h   wud whas hhoct  vin A
#
# lstm_trial:0, iter:299/20000 loss:2.3188374066352844
# generated sequence: W. be wer, ome xo d sart al she
#
#      the pooce wha
#
#     wlid
#     ws Ho the  ou ney ce bacauztha, th
#
# lstm_trial:0, iter:399/20000 loss:2.2010446333885194
# generated sequence: Wjfr ag.
#      an"
#      ""Hon. hs the adr :en alc, Ay he come verg;t"""
#
#
#      oe ingha  hime ert th u
#
# lstm_trial:0, iter:499/20000 loss:2.145652952194214
# generated sequence: Wepass wit sice   p he
#      oup that andiegd
#
#      chaghens op. beri
#      trwe mawn, erld qus op. Ap
#
# lstm_trial:0, iter:599/20000 loss:2.06102370262146
# generated sequence: Whish. Thom
#      "Mhsiciid are tham wimeryoBntre wouble. Thend
#     s a hisvund doclowha sceoiies "Weo
#
# lstm_trial:0, iter:699/20000 loss:2.017680050134659
# generated sequence: Waid the Pain chome hotk the kere weak wot
#      se.
#     came you mrot gpible
#      wheild ontGiit, cer
#
# lstm_trial:0, iter:799/20000 loss:1.9810063171386718
# generated sequence: Whent a me the. I Huthen thel crick. rer rumor the not we hind asein? I pires bin cock. Ho icthe eria
#
# lstm_trial:0, iter:899/20000 loss:1.9621402871608735
# generated sequence: Watimak," thare
#      out andorning sing thatlessed. "It asls fom onock of the for hind ertocat sexnas
#
# lstm_trial:0, iter:999/20000 loss:1.9093379533290864
# generated sequence: Watite ot that juttul you moig; ont; the west bar werane, no rowsiriyor my car ablis to oll his' on w
#
# lstm_trial:0, iter:1099/20000 loss:1.9430005109310151
# generated sequence: WLment, as a clope the datente tothane songing,
#      apestme murt Duhan hnicted hat the Wats, and sap
#
# lstm_trial:0, iter:1199/20000 loss:1.8821545541286469
# generated sequence: We
#      dostiblae you hil wos intulr inco and I ur-ind unetaevery ass outraln's I inshimy ingine list
#
# lstm_trial:0, iter:1299/20000 loss:1.871890950202942
# generated sequence: Wlised papleed weroly. Hea. He coild gof a verphe ersing tont and rery were he
# pa vaol on the was ve
#
# lstm_trial:0, iter:1399/20000 loss:1.8593980550765992
# generated sequence: Wule carneard there.
#      Hepen my. Wreetrowly andcelm Napind I cased, blorer is the
#
#      youmacy.
#
#
# lstm_trial:0, iter:1499/20000 loss:1.8311201703548432
# generated sequence: War's eady. It thim cound that ytu.' I hand
#      gryetinmipce intherting teore
#      a becret que a br
#
# lstm_trial:0, iter:1599/20000 loss:1.84471054315567
# generated sequence: Wy ut it wit is bethines,
#      hald re har
#      whope wackyed his
#      she exabpallly Thotplitt and w
#
# lstm_trial:0, iter:1699/20000 loss:1.797579346895218
# generated sequence: Wisgentouss of
#      thet dape no mehy.'
#
#      "I dightinine was bossiogh disss. Then yousen it ony hi
#
# lstm_trial:0, iter:1799/20000 loss:1.8195915055274963
# generated sequence: Wmente know
#      to treateed at brouke, pollok. "The cigmer in ytwed goar the as a serum as when the
#
# lstm_trial:0, iter:1899/20000 loss:1.7835835111141205
# generated sequence: Wishurc inser lithtinc times, and
#      Amot, a
#      coumis vorich
#      changam, bin, quoned
#      mo!d
#
# lstm_trial:0, iter:1999/20000 loss:1.7728200614452363
# generated sequence: We discaroures broughtainto-owaichent loget so grugef would intowhtrook
#      the prome, and on the ca
#
# lstm_trial:0, iter:2099/20000 loss:1.7721192836761475
# generated sequence: Weand,. I as it?"
#
#      "IWat the deind there asd."
#
#      "You came.
#
#      "Thut that the gording
#
#
# lstm_trial:0, iter:2199/20000 loss:1.7643168210983275
# generated sequence: Wancerdor the exaid, and the id
#      the Elden and rought. Hill the becough, and bet he cound I campl
#
# lstm_trial:0, iter:2299/20000 loss:1.7599297702312469
# generated sequence: We a ncingrere for the tnow this of owe for?
#
#      "Tho beabilly orn strught you," said stsent, the
#
#
# lstm_trial:0, iter:2399/20000 loss:1.7258118760585786
# generated sequence: Waistary ib grost my
#      goan metion
#      ither you derriadly I
#      time leut
#      be to buls
#
#
#
# lstm_trial:0, iter:2499/20000 loss:1.7211557853221893
# generated sequence: We will lity the dittanted to
#      yead Mr. some to gealles is Clail soud corfed are sain of our magt
#
# lstm_trial:0, iter:2599/20000 loss:1.748328776359558
# generated sequence: Wear of my arly tho is in opet cet oucted whater litwerstrove oll this as obword list, rains a hald t
#
# lstm_trial:0, iter:2699/20000 loss:1.724534693956375
# generated sequence: We Veates. Dased, I counted sheasuse, scoched gleysing pice the pine fouch swrysals?" Und into empail
#
# lstm_trial:0, iter:2799/20000 loss:1.7137652087211608
# generated sequence: Wrrayed reasicles sefe; of Me. Hills offer.''          "The fint. hould vetthic I at? But me frivery
#
# lstm_trial:0, iter:2899/20000 loss:1.7295071721076964
# generated sequence: Was symel in
#      grocy messory the
#      mailed werm, Mr; be
#      propationan.
#
#      "Od comon my con
#
# lstm_trial:0, iter:2999/20000 loss:1.6846816146373749
# generated sequence: We wish he lalk the stought oPrestorpand; Encaty a right told he have lack to to fang to doent ow yut
#
# lstm_trial:0, iter:3099/20000 loss:1.68015513420105
# generated sequence: We sacles, atlin, of door and best his proder.
#
#      ":Tark, Mr. Wext to vear. We ofter.
#
#      "Yer,
#
#
# lstm_trial:0, iter:3199/20000 loss:1.673565218448639
# generated sequence: Whim. That has his sheal had conivested in a dunstionas hown, and skeed passiep.
#      "0Ho, which Mc
#
#
# lstm_trial:0, iter:3299/20000 loss:1.6773848247528076
# generated sequence: We Holmes, they."
#
#      "I reiner offeung the
#      the trrame into these which van that t oted romufo
#
# lstm_trial:0, iter:3399/20000 loss:1.689181408882141
# generated sequence: Well unters fan be
#      dare, Lidglessing pobplinclywully heed wime bearr, in mis my was gut to overy
#
# lstm_trial:0, iter:3499/20000 loss:1.6788417375087739
# generated sequence: What was you
#      clots to elver ta
#      courfe, and this? thessor I
#  u
#
#
# lstm_trial:0, iter:3599/20000 loss:1.6445196270942688
# generated sequence: Witalleng blerse it in your you mee through
#      for Sild sleacuully it."
#
#      "Stere's clewned a gr
#
# lstm_trial:0, iter:3699/20000 loss:1.6698382496833801
# generated sequence: What. I ony, at conding of loghan hed was in a worring, and pif-terned quy. And
#      readoros my popi
#
# lstm_trial:0, iter:3799/20000 loss:1.6403500616550446
# generated sequence: We
#      congearg upon a man her be asone now held to be and worts
#      the mo-nous the
#      call, to
#
# lstm_trial:0, iter:3899/20000 loss:1.668542174100876
# generated sequence: Way cheatiessain froch
#      amaket. I'd and to have roodeb wowate the braking
#      Scoiar the ustall,
#
# lstm_trial:0, iter:3999/20000 loss:1.6090565872192384
# generated sequence: Winure purble it, sundon, and Mo
#      very onew a dong, in the dincele and you Adivy, and the singer,
#
# lstm_trial:0, iter:4099/20000 loss:1.6232247567176818
# generated sequence: We it."
#
#      There of the uther hourstoming, So come mion's forte-mames the dear."
#
#      "Hwill ours
#
# lstm_trial:0, iter:4199/20000 loss:1.6228050637245177
# generated sequence: When felsed see farth brous very inother no thee know. A solode. What'mored I was
#      when mad upon
#
# lstm_trial:0, iter:4299/20000 loss:1.5927075040340424
# generated sequence: Whoursinung him, tike, the windossule
#      we shall, in ourselely in you lidened at dable payer him a
#
# lstm_trial:0, iter:4399/20000 loss:1.6569167792797088
# generated sequence: Wa
#      bead oped."
#
#      More of the stond
#      from I shall pidisive
#      werring us a
#      his dre
#
# lstm_trial:0, iter:4499/20000 loss:1.631877257823944
# generated sequence: Was you man glay in look follops dang oore promem aishe, Will re is juched baigg alle weindor, candon
#
# lstm_trial:0, iter:4599/20000 loss:1.6263343060016633
# generated sequence: Where was axconked, some, and that beacress or
#      was a memator." He know is then, great he knough,
#
# lstm_trial:0, iter:4699/20000 loss:1.6170085728168488
# generated sequence: Wan to Ved this was beind an opery promes he disn that only
#      moin alsoous of tcright.
#
#       A se
# lstm_trial:0, iter:4799/20000 loss:1.6046869134902955
# generated sequence: Wursical ever
#      took in the pooge of which a strudve sproos satiequald not of a doccused with prre
#
# lstm_trial:0, iter:4899/20000 loss:1.5893770515918733
# generated sequence: Watson
#      sirck stamas age
#      toof, Morceroup on dade, and not the speach as it, with Mr. - bever
#
# lstm_trial:0, iter:4999/20000 loss:1.5876655876636505
# generated sequence: Wis me what on horummedet of my alicnat as your like to dir.
#
#      "Af
#
#      I send the little to you
#
# lstm_trial:0, iter:5099/20000 loss:1.6379681289196015
# generated sequence: Wate muffeten, it we little; his Mr. I have in quitt for for it!"
#
#      "On alobhe aDcubting Joant di
#
# lstm_trial:0, iter:5199/20000 loss:1.562790710926056
# generated sequence: Whin."
#
#      "Yes," said Holmas, and," said the
#      cour onen knows me inconk lay his mess
#      stap
#
# lstm_trial:0, iter:5299/20000 loss:1.5620728838443756
# generated sequence: Wattled them, have nett
#      on their womumbled my own blook, us Wever tell? He mught
#      teerinn re
#
# lstm_trial:0, iter:5399/20000 loss:1.588114756345749
# generated sequence: Wive calf as juin.  "'
#
#      I had now-steaten tumplize posstung and was a
#      suart," said Frame co
#
# lstm_trial:0, iter:5499/20000 loss:1.5543462562561035
# generated sequence: What my yound, by anster tragglett, I heast."
#
#      "Good to-drivet in the seived was
#      see the be
#
# lstm_trial:0, iter:5599/20000 loss:1.585892288684845
# generated sequence: We should nead had the table, bur yearned that known
#      and mowel-beding and if as she ort' and not
#
# lstm_trial:0, iter:5699/20000 loss:1.5815826165676117
# generated sequence: Wax."
#
#      "We his lolmed friff as I'bley Edod corar loggance, definice a amoughem, to you to the sp
#
# lstm_trial:0, iter:5799/20000 loss:1.5751577270030976
# generated sequence: Watsing and go ared up to the fidy. Watson. Noth of a tathing then rook
#      a risse. Gair, my, whose
#
# lstm_trial:0, iter:5899/20000 loss:1.5491875791549683
# generated sequence: Well timersy ton some-plower for see to at evided to out Witsmented to this
#      breastence
#      inre
#
# lstm_trial:0, iter:5999/20000 loss:1.5476483726501464
# generated sequence: Wy-tudnd, stape out edEmentiows, Mr.'
#      "When I more possoon to pomblies Dadulacked up the serting
#
# lstm_trial:0, iter:6099/20000 loss:1.5418604576587678
# generated sequence: Walfes to the steep dabur
#      yoursthander had tholk has now," he have
#      flan your up to my wooks
#
# lstm_trial:0, iter:6199/20000 loss:1.5623422682285308
# generated sequence: Where meh ob, which senlad, the Bay to see the leghissed cotenty, on you a musily doubt of a nanch."
#
#
# lstm_trial:0, iter:6299/20000 loss:1.5420959889888763
# generated sequence: When shall hap pictiarer his rine of seallo; of my once came us unsterly-ges off Mr. That
#      sure,
#
# lstm_trial:0, iter:6399/20000 loss:1.545268852710724
# generated sequence: Wide laster."
#
#      Strevless a bray did nothin's propose are, "that
#      hell. Everthel, as
#      tab
#
# lstm_trial:0, iter:6499/20000 loss:1.5913393080234528
# generated sequence: Whese, what, for Ster duewn to how my carred some so sind been in this man Jone shame it what,
#      a
#
# lstm_trial:0, iter:6599/20000 loss:1.5484452080726623
# generated sequence: Watsless, me was enough in a see ruak down of. Shiggep stard and
#      with then's you uppent of dives
#
# lstm_trial:0, iter:6699/20000 loss:1.509545294046402
# generated sequence: We for us anger in his coneope,' said then think thought, I
#      sexplessary id fmas, Watson, whater
#
#
# lstm_trial:0, iter:6799/20000 loss:1.5549079048633576
# generated sequence: Winds the feel heardstime it?"
#
#      It's a
#      paifficule. The cond, and Their Parritark, but have
#
# lstm_trial:0, iter:6899/20000 loss:1.5121856892108918
# generated sequence: Wame the ton seem fees a prisently upon the creppened was his Pissoined that the imporsagor up harr
#
#
# lstm_trial:0, iter:6999/20000 loss:1.5517668783664704
# generated sequence: Wap, for Watson, had twisp rethery a grange clear were that he scutl Holmes, is a cruated me howlve
#
#
# lstm_trial:0, iter:7099/20000 loss:1.5318981838226318
# generated sequence: Wtould ever up muck
#      finet, been I trourred upon it ildentay cleenty dark. Batlent like him parca
#
# lstm_trial:0, iter:7199/20000 loss:1.523456755876541
# generated sequence: Whis murder this all, do
#      doubt you.
#      And not tartion and the vinessel briking about bear oth
#
# lstm_trial:0, iter:7299/20000 loss:1.5216757297515868
# generated sequence: Wand that his promed withhat I have clife, The deevms
#
#      siek came a come
#      shind no funse kno
#
# lstm_trial:0, iter:7399/20000 loss:1.5117349302768708
# generated sequence: We center this you was occepp over
#      and my setting evenow noildard, twing?"
#
#      "Hele other, it
#
# lstm_trial:0, iter:7499/20000 loss:1.5335719120502471
# generated sequence: Winen. The
#      pootiwh the mearacted fron I
#      fiorty puth to to alan? He would once, which get ho
#
# lstm_trial:0, iter:7599/20000 loss:1.5275408613681793
# generated sequence: What with shetts loft that strunges up. How danger that shell very nose no belast what then what woul
#
# lstm_trial:0, iter:7699/20000 loss:1.5168031394481658
# generated sequence: Whis his goop, and Howld has yon to not ramen hands, Watson's," I antind in
#      in my should all no
#
# lstm_trial:0, iter:7799/20000 loss:1.4954504883289337
# generated sequence: Window that and what surpremencan and even of the rempressocuilst that schidey carder Holmes Appained
#
# lstm_trial:0, iter:7899/20000 loss:1.5486655843257904
# generated sequence: Winds, in the headrous tursed a very and
#      with maniagew.
#
#      He sionl Junge his fellow
#      to
#
# lstm_trial:0, iter:7999/20000 loss:1.5298099184036256
# generated sequence: We as Grooded, and on Lemersed to the had in cuils, the
#      died the feat carried?"
#
#      As I have
#
# lstm_trial:0, iter:8099/20000 loss:1.5219376254081727
# generated sequence: Wuthing-about
#      offlem that I have darged, unsigured exhined in kest,' she can the vereft
#      as
#
# lstm_trial:0, iter:8199/20000 loss:1.5059145951271058
# generated sequence: Watsable--here in the readoned the blash from three flonger of
#
#      "Came it buc by this just
#
#
# lstm_trial:0, iter:8299/20000 loss:1.5165764486789703
# generated sequence: We head man waited the cince. Hope! Lond upprour!" He you have is a realer.
#
#      "They everylataled
#
# lstm_trial:0, iter:8399/20000 loss:1.5104822623729706
# generated sequence: Whengy of in
#      awattle ver have dever of the way my agit. Durg all the keep for clear asted air hi
#
# lstm_trial:0, iter:8499/20000 loss:1.5072239804267884
# generated sequence: Wawly derticullic duify-back me who cap ourled and
#      three to be a grost about pover into
#      we
#
# lstm_trial:0, iter:8599/20000 loss:1.491332459449768
# generated sequence: Wat of't to
#      I buth -8bes roved what I remarks, ig."
#
#      "We dan enouge in my that were strang
#
# lstm_trial:0, iter:8699/20000 loss:1.4904118716716765
# generated sequence: Whipe. An askerset least you seeds with my wasp were duads hands was feelly our broan one from moriol
#
# lstm_trial:0, iter:8799/20000 loss:1.4931018674373626
# generated sequence: We was be outselves?"
#
#      You well thing with eskned, nothishows that name colder. On suid I'm alwe
#
# lstm_trial:0, iter:8899/20000 loss:1.4912942278385162
# generated sequence: Watcurn that a voig to the compining
#      not
#      Joner searss the moon throry booking roket, and yo
#
# lstm_trial:0, iter:8999/20000 loss:1.5000700783729553
# generated sequence: We are wought
#      at your and matter him heach at a mouth the Sart night, Rudge you."
#
#      "That th
#
# lstm_trial:0, iter:9099/20000 loss:1.5107102763652802
# generated sequence: Wtourd was a over of hintered and a sud a quarter you; so thave whome
#      seen most over to'sm face'
#
# lstm_trial:0, iter:9199/20000 loss:1.4912380862236023
# generated sequence: Wan. Fores the bid Yordies and ster you aid baddder."
#
#      Lory
#      over being of the dese of my se
#
# lstm_trial:0, iter:9299/20000 loss:1.5241867589950562
# generated sequence: Wall this scegs yer you would thount an extremed of the
#      swattles
#      rester."
#
#      The
#      fe
#
# lstm_trial:0, iter:9399/20000 loss:1.4995526099205017
# generated sequence: Wh the minem find paper with a carred who dopary thring Mchenches. Those, to accimations a fallow
# lstm_trial:0, iter:9499/20000 loss:1.4737525701522827
# generated sequence: Wallun. Then I thinged and
#      here. Be seeding the myself confius of the hoesure, shal man
#      jus
#
# lstm_trial:0, iter:9599/20000 loss:1.509548726081848
# generated sequence: Watson, for rightingial hore unnoted unongioutly derice offulid ut we could have been insignts of thr
#
# lstm_trial:0, iter:9699/20000 loss:1.490333341360092
# generated sequence: Watser with mintish or firs
#      frighten
#      nypotcicire."
#
#      "but
#      is mestilae
#      a chami
#
# lstm_trial:0, iter:9799/20000 loss:1.4900822257995605
# generated sequence: Watson, in implassive upof quair of lew
#      elgeness, and I sat only which Londocals. I saw had Lond
#
# lstm_trial:0, iter:9899/20000 loss:1.4843220591545105
# generated sequence: Wa'd hus your proment. We call je-prepartion.
#      He can well the whome had want in his fintions.
#
#
#
# lstm_trial:0, iter:9999/20000 loss:1.4638886284828185
# generated sequence: Wh, of his mush hope not surriestion-spear's rumper his showns.
#
#      "Mouse had been ablust of now,
#
# lstm_trial:0, iter:10099/20000 loss:1.4546336400508881
# generated sequence: Wish in his coffichioned and timation,
#      crosed at the gravoly blaces untim oldoughtt right, and c
#
# lstm_trial:0, iter:10199/20000 loss:1.4803075182437897
# generated sequence: Wa shat. Driverhure of the strutber. He has can one of the chair, and that speat comparsing we have b
#
# lstm_trial:0, iter:10299/20000 loss:1.5103817665576935
# generated sequence: Wh me. Sud and as Lon's other his cooving too dosed to him.  'Yes," care mist. You armive hours, Lest
#
# lstm_trial:0, iter:10399/20000 loss:1.4863179886341096
# generated sequence: Watson are, for this speed the
#      instain, the. To betast seee there come as list that do, with his
#
# lstm_trial:0, iter:10499/20000 loss:1.4998399066925048
# generated sequence: Watsom, which I confort. Myshousesew. The prover of so. "For there was incoopean of astionmed everlow
#
# lstm_trial:0, iter:10599/20000 loss:1.5023079645633697
# generated sequence: We, Yor sevenly from plance love a nead you
#      two pabling sunching bodet
#      hand,
#      with
#
#
# lstm_trial:0, iter:10699/20000 loss:1.4541371619701386
# generated sequence: Walle luble Frrenkak of the expeason grays recenty to greakly that I sallab resigians, rose he but wi
#
# lstm_trial:0, iter:10799/20000 loss:1.4657772159576417
# generated sequence: Was
#      reportloce
#      nor one, in the pactage of the two a greased eressed upalled of his corrente
#
# lstm_trial:0, iter:10899/20000 loss:1.4709239399433136
# generated sequence: Whins to stillly something of he will you got the outs, surctide we man cat sure to have fhertoch to
#
# lstm_trial:0, iter:10999/20000 loss:1.470468249320984
# generated sequence: Whit
#      despose care that is to living and men, whine dy is as broupting man."
#
#      "She was non s
#
# lstm_trial:0, iter:11099/20000 loss:1.4932354283332825
# generated sequence: Watson that bethered this if we kepped and nothers who has read fleg-liponed of Semfory, he fellought
#
# lstm_trial:0, iter:11199/20000 loss:1.4574441802501679
# generated sequence: Wapsittered from I so-doves the congeave. That sixolise through was forgath having beacting." Have ar
#
# lstm_trial:0, iter:11299/20000 loss:1.4881765592098235
# generated sequence: Wh were Basker, his manners' wish and daigrork come to invest many subcution cauld Pattenk
#      good
#
# lstm_trial:0, iter:11399/20000 loss:1.4845490920543671
# generated sequence: We low see and Stade of it?" esterale. He could recay hournes the
#      you ideet?"
#
#      "Tha marriou
#
# lstm_trial:0, iter:11499/20000 loss:1.4688341963291167
# generated sequence: Walled a braved a face Round that," said Holmad about I never working
#      qurery to his indest rove.
#
# lstm_trial:0, iter:11599/20000 loss:1.4757085990905763
# generated sequence: Watson, in her cal he gething that clip knew, then had, he. But's remirst was prea. Dous
# .     a shal
#
# lstm_trial:0, iter:11699/20000 loss:1.505437159538269
# generated sequence: We he
#      been left and but Marulating it. You don't chaping that feet be in her do shing to any kne
#
# lstm_trial:0, iter:11799/20000 loss:1.4521359539031982
# generated sequence: Williend had dimm.
#      -hear me are. Is found or fation. A wats. Ohver hapobaty. A! I should. And I
#
# lstm_trial:0, iter:11899/20000 loss:1.4969242775440217
# generated sequence: Watson' stother we'ke. She,''
#
#      Pray."
#
#      "That's me
#      young the understand albors, through
#
# lstm_trial:0, iter:11999/20000 loss:1.4640574026107789
# generated sequence: We laurtaves, but
#      date.
#      Holmes.
#
#      "Noths
#      be
#      down ard to-nes. "I have he
#
#
# lstm_trial:0, iter:12099/20000 loss:1.4580540430545808
# generated sequence: Wammeserest gart in the trasbsters.
#
#      My fire you stabde factom. At
#      the dresse sunsyor, Wats
#
# lstm_trial:0, iter:12199/20000 loss:1.4824115121364594
# generated sequence: Watsored Herrmfilc. "The preced my corred with the notesere the goo's can rooms, Jack.'
#
#      That ar
#
# lstm_trial:0, iter:12299/20000 loss:1.4703704941272735
# generated sequence: Wil,-"Did I reacises in the own it, "there was wirdo thougue the tray it
#      abod-gerdivourey and te
#
# lstm_trial:0, iter:12399/20000 loss:1.461536282300949
# generated sequence: With him case scringess, trieety I'pped it. "Nevin that I
#      more in the starticn smark
#      of ver
#
# lstm_trial:0, iter:12499/20000 loss:1.4760341405868531
# generated sequence: Wathoul
#      have forthing. I markerly edge.
#
#      "It may as yourged, the mattersoud the confitell a
#
# lstm_trial:0, iter:12599/20000 loss:1.4673332071304321
# generated sequence: We are armand what bleand
#      for the man's a
#      walled you alreads into unneasive Didmand
#      wi
#
# lstm_trial:0, iter:12699/20000 loss:1.4316702592372894
# generated sequence: Where.
#
#      I shortified, where he varetulas trill, but the moment of the
#      room which we friend
#
# lstm_trial:0, iter:12799/20000 loss:1.4482135212421416
# generated sequence: Wammed to
#      the
#      sleened
#      yet.
#
#      "A 't back bultish, but I in though to followes
#
#
# lstm_trial:0, iter:12899/20000 loss:1.4600147771835328
# generated sequence: Wingling diffient at there and
#      muss bifly procied. "He wife holes, and the most somewith black o
#
# lstm_trial:0, iter:12999/20000 loss:1.4432049775123597
# generated sequence: Wisisply had the thee downened, and securainous hese spoke in operello, and must be alson, who has ba
#
# lstm_trial:0, iter:13099/20000 loss:1.4378199076652527
# generated sequence: Wish his brither.
#
#      "No, I save and bring of pantle to see out?"
#
#      "Iy was importab," said Bo
#
# lstm_trial:0, iter:13199/20000 loss:1.440652116537094
# generated sequence: Wand
#      able to up probled his chrave charr far for blangent," said we so us and took it arresary h
#
# lstm_trial:0, iter:13299/20000 loss:1.4730790483951568
# generated sequence: Wton,
#      and I do and thing of e ancal, "critce to a wards.
#
#      "All the cusinir. We made in such
#
# lstm_trial:0, iter:13399/20000 loss:1.4495340836048127
# generated sequence: Wal as maured a deville and
#      glass of the crumble with, elders abottroor to acquenty tofs as this
#
# lstm_trial:0, iter:13499/20000 loss:1.4468511247634888
# generated sequence: Wis on the late it letling--a
#      layed Sirn, evening
#      with my flush
#      ask reepon insome on t
#
# lstm_trial:0, iter:13599/20000 loss:1.459238908290863
# generated sequence: Wuptal crime Ratter how
#      had sat it convernion while the
#
#      in up. You save is very wnitton sh
#
# lstm_trial:0, iter:13699/20000 loss:1.4373731958866118
# generated sequence: Wal and proudre and ranu!"
#
#      "'And harungly Smolot," said for you, told to
#      my hand you, ther
#
# lstm_trial:0, iter:13799/20000 loss:1.4437583780288696
# generated sequence: Whers of an eitreminion to same advice to the recoty
#      glad there jetting. What is for into tnive
#
# lstm_trial:0, iter:13899/20000 loss:1.398167052268982
# generated sequence: Wits fire," said he "Nor diflice," he
#      darce side-righ, and entral wapt-on in a slitere-bleck abo
#
# lstm_trial:0, iter:13999/20000 loss:1.434702651500702
# generated sequence: Whem that on the child. "However, no sioner." said feart to graurt-tinily. "That I well, servately, a
#
# lstm_trial:0, iter:14099/20000 loss:1.4611077857017518
# generated sequence: Wilk broken apper agon the toon the pouth to despored a door
#      have purdiat adding as the
#      whi
# lstm_trial:0, iter:14199/20000 loss:1.438999570608139
# generated sequence: Whis asterstab eits Lifers we belent-Murreed to it but, when Mcrorded
#      misbed
#      to draved to D
#
# lstm_trial:0, iter:14299/20000 loss:1.4685856342315673
# generated sequence: Watson,
#      Shrilbly only
#
#      I am Godgous. It is every fellow any inforth, as thinkied, it not,"
#
# lstm_trial:0, iter:14399/20000 loss:1.4112021386623383
# generated sequence: Whis, surdenled the
#      conshers."
#
#      If you
#      head the quiting
#      pleased to the manters, t
#
# lstm_trial:0, iter:14499/20000 loss:1.4492441618442535
# generated sequence: Wat that I tell more.
#      Aky off to my fellow of the moor exagan back figvally on a hunder."
#
#
#
# lstm_trial:0, iter:14599/20000 loss:1.4258287954330444
# generated sequence: Wull she exashess pabable grent night. But not
#      terrrapinase divillant has. But Cyle care to clas
#
# lstm_trial:0, iter:14699/20000 loss:1.429978438615799
# generated sequence: Wimsw,
#      as he could hands as a still, and had name of these from wore eepasse Inded topet at mist
#
# lstm_trial:0, iter:14799/20000 loss:1.4420830142498016
# generated sequence: Watser, so I heard in its ded thoughted a spool. In
#      terribable strew to note I lips to three of
#
# lstm_trial:0, iter:14899/20000 loss:1.4126185059547425
# generated sequence: Way adeage owf has
#      mam rown on imstance. May
#      yet!  he happenes expras. Thesarypalked commin
#
# lstm_trial:0, iter:14999/20000 loss:1.4527739334106444
# generated sequence: Whis lady of a
#      most mat Loud-haPted our prosorate inclagged and, rrase.
#      Propmed. Hell-haged
#
# lstm_trial:0, iter:15099/20000 loss:1.4288238978385925
# generated sequence: Wase more fashioned blied.'
#
#      Marage that he warned hopoim.'
#
#      "So
#      the prefeck into ther
#
# lstm_trial:0, iter:15199/20000 loss:1.4507382476329804
# generated sequence: Watson betteed us he had been drobbon had sureed to his gue? No obself to him to purdo sech a fear wa
#
# lstm_trial:0, iter:15299/20000 loss:1.4108232629299164
# generated sequence: Widst as then you came enidocully
#      Least a shough to New is to to dallopy out of hould rather
#
#
# lstm_trial:0, iter:15399/20000 loss:1.4274291646480561
# generated sequence: Wauld, his toors for drive, and us somethor
#      to
#      himoation, course the common in earmd when t
#
# lstm_trial:0, iter:15499/20000 loss:1.439331181049347
# generated sequence: Wan adost into the chay wante was purpession. Led I low scares' seepers.
#
#      "By very bouth rught o
#
# lstm_trial:0, iter:15599/20000 loss:1.4051498460769654
# generated sequence: Wate comman when his few his Grear Gor. Which I am things, and for the invelebt. Yet us was the now s
#
# lstm_trial:0, iter:15699/20000 loss:1.4068401783704758
# generated sequence: Wimert up in much mirring until theary anare of the
#      was a centin my country, in her asterer that
#
# lstm_trial:0, iter:15799/20000 loss:1.453412264585495
# generated sequence: Wis lume, and a ashing to holk latter bashed squere
#      addice,
#      which conlenth, desired how Stu
#
# lstm_trial:0, iter:15899/20000 loss:1.4494717252254485
# generated sequence: Wous it nighthuld acted
#      dark of answertores consideroet. I have at the charrance which we suspos
#
# lstm_trial:0, iter:15999/20000 loss:1.4059612822532654
# generated sequence: Wy
#      went from withly I
#      place, of tu, I
#      can have been some can, and offered peations.
#
#
#
# lstm_trial:0, iter:16099/20000 loss:1.4319984424114227
# generated sequence: Walf you."
#
#      There dest profed or abserbary of other staurd mast just but firlfok,
#      and the c
#
# lstm_trial:0, iter:16199/20000 loss:1.4405176830291748
# generated sequence: Wake through."
#
#      Holmes trueched. There found there were the possitt. If if is don't kn upon him.
#
# lstm_trial:0, iter:16299/20000 loss:1.4416169428825378
# generated sequence: Wilde it. Noteession intingreveling with the
#      sir no ogs, inquive's of the room. Witting."
#
#
#
# lstm_trial:0, iter:16399/20000 loss:1.4219088101387023
# generated sequence: Wad to not me to the chall and slees Forking they armhact if the
#      has a dyessed away that we rear
#
# lstm_trial:0, iter:16499/20000 loss:1.4273705339431764
# generated sequence: Wad happones to secret, "wangom; to the earghable
#       into their brugsing at umbendies, and a matte
#
# lstm_trial:0, iter:16599/20000 loss:1.4354344868659974
# generated sequence: Willowg Scordures. "I am sofr entran of mery been croside as
#      deed amought here.
#
#      "Yan Gell
#
# lstm_trial:0, iter:16699/20000 loss:1.44956876039505
# generated sequence: Watson that
#      been must nourmed, Birlosing about well repart."
#
#      "By suartens one villa.
#
#
#
# lstm_trial:0, iter:16799/20000 loss:1.4376919209957122
# generated sequence: Wits ifter impre of it, sir, Adate to your, and my ot of him which he had first of them and by if he
#
# lstm_trial:0, iter:16899/20000 loss:1.417091873884201
# generated sequence: Wave hould, Watson," said some weakes, from repin that helvers after."
#
#      Only was poised him
#
#
# lstm_trial:0, iter:16999/20000 loss:1.416107698082924
# generated sequence: Whis 'the worders about a fourn to grown that the
#      place
#      mack many intoders. Why
#      addach
#
# lstm_trial:0, iter:17099/20000 loss:1.4113770174980163
# generated sequence: Wous wouldn be eyes next,
#      fited you."
#
#      "'It is ence can
#      comhin."
#
#      "Yes, I
#      co
#
# lstm_trial:0, iter:17199/20000 loss:1.4140861570835113
# generated sequence: Wavise that I should pears."
#
#      "You'm has have
#      which is for thing with face ahaute, with me
#
# lstm_trial:0, iter:17299/20000 loss:1.402092901468277
# generated sequence: Wa sog.t
#      tob, my trieve. Howevion and seew get Sir Colonectiate!' I came large heads to whetho d
#
# lstm_trial:0, iter:17399/20000 loss:1.3977533400058746
# generated sequence: Well lady laid out the deally usually
#      armurtance, danger the
#      sile, sir. Ikening from o'clec
#
# lstm_trial:0, iter:17499/20000 loss:1.3965041327476502
# generated sequence: We siven of bardess.
#
#      "Luss to goar life
#      passed that not neiption forable of
#      injugior
#
# lstm_trial:0, iter:17599/20000 loss:1.4250621700286865
# generated sequence: Wall Cut it was covered smemined and whin he cull, and leret bet anstail much of thinke, any occurred
#
# lstm_trial:0, iter:17699/20000 loss:1.393876532316208
# generated sequence: Watson that the Jost to     inded of these passaphestand--"I itstasted.
#
#      "Pravaged, man were jo'
#
# lstm_trial:0, iter:17799/20000 loss:1.429194016456604
# generated sequence: Walther way. There would gonk, but with once of profores.
#
#      "It is yourself to horming passake ch
#
# lstm_trial:0, iter:17899/20000 loss:1.4123404955863952
# generated sequence: Watsidely,
#      as which was profefully skee be some table as all the cheech which confiring which No
#
# lstm_trial:0, iter:17999/20000 loss:1.392188230752945
# generated sequence: Wimply day being before disto the humom the path
#      mequay
#      carried no inso unon
#      firefe of
#
# lstm_trial:0, iter:18099/20000 loss:1.4068473768234253
# generated sequence: Wave a cond between weah
#      as he here," said Holmes as us
#      the matter that, ystimate of Nordlu
#
# lstm_trial:0, iter:18199/20000 loss:1.4206786775588989
# generated sequence: Wis o-lugners short exmetement, "convouting upon the little bload to keed the git is the hee we shand
#
# lstm_trial:0, iter:18299/20000 loss:1.4038587093353272
# generated sequence: Watson, and
#      meanuster as
#      over this him too, and expect gate on on, places with expecious to
#
# lstm_trial:0, iter:18399/20000 loss:1.428705382347107
# generated sequence: Wit
#      roomer. My sails, pleckece into this, into rang upon     ded
#      of minele zemet when have
#
# lstm_trial:0, iter:18499/20000 loss:1.4145318055152893
# generated sequence: Watson! Lan shoulde his lew upon the letter Aver grilfer his back.
#
#      Mchrosishont
#      of beres-u
#
# lstm_trial:0, iter:18599/20000 loss:1.4394045758247376
# generated sequence: Wis it to anoth and twis, and the whole shapped-curroy his
#      invest for the it bith round upon
#
#
# lstm_trial:0, iter:18699/20000 loss:1.408135621547699
# generated sequence: With, connickle in noro. Only. Ag. Twinkness logguine dicall invall. He toward
#      been or the rmoth
#
# lstm_trial:0, iter:18799/20000 loss:1.4449489879608155
# generated sequence: Willed his way."
#
#      "Acry."
#
#      "You prefure still Gock wirchy refally of any weep relight a spr
# lstm_trial:0, iter:18899/20000 loss:1.4030204129219055
# generated sequence: Wall back within the tration, and very day."
#
#      "How firston, when your
#      tried--sharr England
#
# lstm_trial:0, iter:18999/20000 loss:1.4182433044910432
# generated sequence: Wat that is to belinise fears of the front Sir loud not papsin, and was meinest before to sils then u
#
# lstm_trial:0, iter:19099/20000 loss:1.4269112503528596
# generated sequence: Won, is they amawous--it's that that
#      Holmes stece of the corriaglam, Eld it heabet.
#
#      "'One.
#
# lstm_trial:0, iter:19199/20000 loss:1.4359728050231935
# generated sequence: Wive read birditoatted before a traced on occeported eppey but a
#      understood me?"
#
#      The fame,
#
# lstm_trial:0, iter:19299/20000 loss:1.4026288819313049
# generated sequence: Whis
#      was spingorced the case."
#
#      Was the
#      ladiald over
#      these anchair, Cirst, one
#
#
# lstm_trial:0, iter:19399/20000 loss:1.4290860331058501
# generated sequence: Will and coor, he study a hands to by introop, moterpy
#      without I moves no she.   for it is exami
#
# lstm_trial:0, iter:19499/20000 loss:1.4095886421203614
# generated sequence: Wild betwowed, away of a distrod and in Rond.
#
#      "And much of vioushivituly of our things should b
#
# lstm_trial:0, iter:19599/20000 loss:1.4015932893753051
# generated sequence: Welp. I thoughtring at the tawly.
#
#
#
#
#
#
#                     shall deer. You Sher to ourse untin seem
#
# lstm_trial:0, iter:19699/20000 loss:1.3989637660980225
# generated sequence: Wown has
#      chel, and cay came a hart smear after restrage-pass was eyes for condinuame to no of yo
#
# lstm_trial:0, iter:19799/20000 loss:1.4232324409484862
# generated sequence: Wyou the whole
#      plampered to Breting out
#      warrastened by the night, and the does no depanter.
#
# lstm_trial:0, iter:19899/20000 loss:1.3909275579452514
# generated sequence: Well, heeviroust
#      the Polders, and we can stone of which it," said our  it had hur during spose
#
#
# lstm_trial:0, iter:19999/20000 loss:1.443973549604416
# generated sequence: Well cheeman murder night of a know chambard in the vising accuments of the the possible and was own
#
# lstm_trial:1, iter:99/20000 loss:3.0564542627334594
# generated sequence: Wt<"aon
# wee  achre,nhld
#   lt tmphtSav h
# s I
# ole    etin e he    hmseiu  uoe br h ne tppbvf   thvet
#
# lstm_trial:1, iter:199/20000 loss:2.6599879384040834
# generated sequence: Wreuship ao ,  erdsonk  teot Immy{skwomonin e eed Jhe! "tyescetoCot an
#  ' y mearud se iom! t sole ver
#
# lstm_trial:1, iter:299/20000 loss:2.3354322481155396
# generated sequence: W2]y han hoamsdeplumere too
#       "serertkls o  dopt fandean hcos tourptved whas atdenMbyamy he Soo-g
#
# lstm_trial:1, iter:399/20000 loss:2.1942187321186064
# generated sequence: Wprisseve dtr mel as sertare an incene an By th uf ne ad elasvou weut
#      deWt o s yithil f ancers t
#
# lstm_trial:1, iter:499/20000 loss:2.1447674012184144
# generated sequence: Wcething sofkedning sa me an ferise couper, dorl fukl thece Mint surted, int,
#      Id af"Tgerord I Th
#
# lstm_trial:1, iter:599/20000 loss:2.0896412706375123
# generated sequence: Weat as you
#      and
#      mang Gobk,-ysest. subnort in nid-mest as soon of outhing ay thas Sis to
#
#
# lstm_trial:1, iter:699/20000 loss:2.0715736782550813
# generated sequence: Wgoosoes it mand an bayinise Mroute if lomtth
#      ampousd coren werodre, wa at the last
#      gonond
#
# lstm_trial:1, iter:799/20000 loss:1.9901717603206635
# generated sequence: Wnetel cowiges a pyarrIn, Mth hin Hotmers sole
#      enmeveld as o fal jurl.
#      nBat Mr ippingus. I
#
# lstm_trial:1, iter:899/20000 loss:1.9710856473445892
# generated sequence: Wa,"
#
#      a's mask wereled ould damy
#      sorveedd-"Thon they but ldo-ghew it suskined'wny wishser.
#
# lstm_trial:1, iter:999/20000 loss:1.9407951259613037
# generated sequence: Wof mraeare@ 9fepes of m and by neat the sovelgarad eveated as  ux
#       f ow abe and cow of I ald th
#
# lstm_trial:1, iter:1099/20000 loss:1.9379188001155854
# generated sequence: Wo cithhest oon to his wi
#      Durllodoond
#      unaus creygh whou of lioted weld
#      thad elakt me h
#
# lstm_trial:1, iter:1199/20000 loss:1.8812532198429108
# generated sequence: Wher!turicry, asd higt was orny carle mover you a tere is. "You my el ovint wand nould fist har coudo
#
# lstm_trial:1, iter:1299/20000 loss:1.9150207674503326
# generated sequence: We whadming. the cpousry. I bee confed of that ut wime wimala
#      vno" wat erong he corges a domenin
#
# lstm_trial:1, iter:1399/20000 loss:1.8959929144382477
# generated sequence: W shave had thear ads of, Magw
#      shar tho mant fard wheing that he wat at
#      wime ges cade bread
#
# lstm_trial:1, iter:1499/20000 loss:1.8915041029453277
# generated sequence: Wet of
#      and I hey tow you thas and fouthindofirgered
#      I lemersyouse an who The ening the spok
#
# lstm_trial:1, iter:1599/20000 loss:1.8619245827198028
# generated sequence: Wallisy core antluenont ittreeld fown lase naobery Chemole, buld houge wat artick theutcon mentarmes.
#
# lstm_trial:1, iter:1699/20000 loss:1.8144205451011657
# generated sequence: Wingaterrame," the sourd the came tras crat.f
#      so blird liter, she'r the pokming that his ques co
#
# lstm_trial:1, iter:1799/20000 loss:1.8351228356361389
# generated sequence: Wquilslis, mistr that a baker inter. Thes Mighalt quess sut ander. We
#      at shearion over."
#
#      "
#
# lstm_trial:1, iter:1899/20000 loss:1.8559131181240083
# generated sequence: Worrygrentler
#      Mrzichelint, bcen freashone an's erorol, and sur you she
#      telveses whishe houm
#
# lstm_trial:1, iter:1999/20000 loss:1.8148884296417236
# generated sequence: Was had the cart, the beenter sore Mid indess, boze?"
#
#      "Ench."
#
#      "That grimes. Ane a sugr."
#
#
# lstm_trial:1, iter:2099/20000 loss:1.7786364829540253
# generated sequence: Wentadess and
#      peprepledle me trame befy
#      his expeppeguls. He of aspencictiet. Id thewe that
#
# lstm_trial:1, iter:2199/20000 loss:1.8048447680473327
# generated sequence: Wouth inte.
#      " I wa faicesouliend, whe niss
#      with my upmains blo glok, Noke't simping sime th
#
# lstm_trial:1, iter:2299/20000 loss:1.7491431605815888
# generated sequence: Wally of the some one gant-ther as thinke?"
#
#      our . shas the trugnes allen
#      fly se. Ittering
#
# lstm_trial:1, iter:2399/20000 loss:1.7797174525260926
# generated sequence: Wwice may3ry.
#
#      "Yever see. If surs obloss to may
#      ulk most the goon. I lake so in
#      that
#
# lstm_trial:1, iter:2499/20000 loss:1.7372449481487273
# generated sequence: We of to stot,
#      neassaben."
#
#      whide criap, anry quiit.
#
#      "I Fery," hay; that Selfach. "I'
#
# lstm_trial:1, iter:2599/20000 loss:1.7517589735984802
# generated sequence: Whagred and of foll? Gomteg fiater having had by had me of no indost, with stame the has daabaning fr
#
# lstm_trial:1, iter:2699/20000 loss:1.727946447134018
# generated sequence: War
#      hagher.h
#
#      "You cauld tik, now, out, and his dafe himmert, from his luitcrephous
#      lo
#
# lstm_trial:1, iter:2799/20000 loss:1.72436665892601
# generated sequence: Wes litce to to bick, consot to me moin found the call dess waicrafould fransy was feresse cat dack,
#
# lstm_trial:1, iter:2899/20000 loss:1.6974433910846711
# generated sequence: Whink he cemen upon an inturesce in hand yeught the popacy from.
#
#      "He raug,
#      his anour."
#
#
#
# lstm_trial:1, iter:2999/20000 loss:1.7103213357925415
# generated sequence: Wrytrailed word minting alfesservom. The toked you."
#
#      The ouryaw of the asceded him
#      teture
#
# lstm_trial:1, iter:3099/20000 loss:1.7116853034496307
# generated sequence: We rive, inderdainers, that
#      gathing hid itiching?'
#   "lewor, suppher of is. I have then when t
#
# lstm_trial:1, iter:3199/20000 loss:1.7060141336917878
# generated sequence: Wond a trught - "Rrewson any my pecempion and he that of the had yound deance to hich to a gaith to b
#
# lstm_trial:1, iter:3299/20000 loss:1.7049466109275817
# generated sequence: Welly evinghess intwhent his? them-trangs I con your bethis wird, Nowsed minciagutarshiching hifesad
#
# lstm_trial:1, iter:3399/20000 loss:1.6978646636009216
# generated sequence: We it
#      callushed
#      take lozew of the
#      tont pary oullows of the ring, uprejustiolt aftlest
#
# lstm_trial:1, iter:3499/20000 loss:1.681312643289566
# generated sequence: We the!
#      stire for Rommer has ift
#      that hosk becolled ablusemedold."
#
#      "Unth she this to
# lstm_trial:1, iter:3599/20000 loss:1.6850275480747223
# generated sequence: We in;
#      ham--incould but by quilig."
#      "And the somenwooust man my found at in he werp me, Whi
#
# lstm_trial:1, iter:3699/20000 loss:1.662943445444107
# generated sequence: Wellay it
#      Hellant.
#      Holme--comerre that is excor'll, well night even his and up eterack and
#
# lstm_trial:1, iter:3799/20000 loss:1.669926141500473
# generated sequence: Was ably rackontert upon the lewner a grabre
#      shing on they Planger
#      shan, of there. Ald coun
#
# lstm_trial:1, iter:3899/20000 loss:1.680722985267639
# generated sequence: We had doun, and very has a paned to pillems to thought that no nare to mettle have Holmes, "have bec
#
# lstm_trial:1, iter:3999/20000 loss:1.6567256605625154
# generated sequence: Wave poss and Homming, Greact in the fairhto more whuch.
#
#      "He hall
#      hourse you in he was the
#
# lstm_trial:1, iter:4099/20000 loss:1.6540985369682313
# generated sequence: Wit!" was a stied.
#
#      I am us bennce," sucket.
#      Applief to bud, ans witt woring the room fisse
#
# lstm_trial:1, iter:4199/20000 loss:1.6662939715385436
# generated sequence: Whis "Lyt
#      you sides of a then's protices fealatis, and as the doly, "which with somy goosse bint
#
# lstm_trial:1, iter:4299/20000 loss:1.6667196571826934
# generated sequence: Wher, her rullad hard rainch, of the ond knever a arry. She trocking howen, and plown tudertabver, th
#
# lstm_trial:1, iter:4399/20000 loss:1.6556212747097014
# generated sequence: Was moon and her daids in werr awain tamb me ablut wild, I window might
#      Drot and think hum she w
#
# lstm_trial:1, iter:4499/20000 loss:1.6466015017032622
# generated sequence: Whan there who in olves, and on me prestwor duss.
#
#      "The pape. Hadrorn."
#
#      "Wholesed, "Holmes
#
# lstm_trial:1, iter:4599/20000 loss:1.6712838363647462
# generated sequence: Why stered. The can dowalse
#      diys draks it with the sarded. I gould not. Oh, what I she me mushe
#
# lstm_trial:1, iter:4699/20000 loss:1.6726903557777404
# generated sequence: Wal
#      bet wences which
#      now thwing veive on other, lountlave to -to may bather on the was with
#
# lstm_trial:1, iter:4799/20000 loss:1.6412684726715088
# generated sequence: We turrd."
#
#      "I semplich, to from fooltain to charm, the hrirry us you left that we enter sturte
#
# lstm_trial:1, iter:4899/20000 loss:1.645034430027008
# generated sequence: Wably reLezpla."
#
#      "You shagesing in the
#      all thwille," said one would poor."
#
#      "I me an
#
# lstm_trial:1, iter:4999/20000 loss:1.627545303106308
# generated sequence: We had glirglamust, not appeapling
#      agrode in the
#      pepelt ey Lut. I Wandos eyes, and not cear
#
# lstm_trial:1, iter:5099/20000 loss:1.6157658183574677
# generated sequence: We,"  alls of the gooshed,
#     ound, Watsod faclif his noted, Watson.
#
#      "I? Yes?"
#
#      "They is
#
# lstm_trial:1, iter:5199/20000 loss:1.6088804173469544
# generated sequence: Wh I should the misins about it is now con that the breat!" I rouker
#      out
#      Let-'the very do,
#
# lstm_trial:1, iter:5299/20000 loss:1.6204901123046875
# generated sequence: Watted of that that courddent I hear stapted it enew would enter to fold, Was, Poll secpenting't were
#
# lstm_trial:1, iter:5399/20000 loss:1.5991408455371856
# generated sequence: We had going abmelver him, in comacks to deedonolage tured, justure.
#
#      "Well in a sid. Him lient,
#
# lstm_trial:1, iter:5499/20000 loss:1.6457251477241517
# generated sequence: Wall they reiminarrings."
#
#      Wanning behill fomants of oven Worssooker and sceated, coppleaned me
#
# lstm_trial:1, iter:5599/20000 loss:1.5818904161453247
# generated sequence: Weaving teve onrestant to the sturt.
#
#      Sadertom, and nother in goth had dooecler
#      of his plas
#
# lstm_trial:1, iter:5699/20000 loss:1.6168600285053254
# generated sequence: Wought in berobd could
#     +ith. 'My nothing shatter ask I
#      houmon, betill dise conskes.  Lugsts
#
# lstm_trial:1, iter:5799/20000 loss:1.5955510425567627
# generated sequence: We might In oncems whout infelf, you did ey, to up the pocchine."
#
#            Than I could, my remcap
#
# lstm_trial:1, iter:5899/20000 loss:1.565101066827774
# generated sequence: Weld diving and her of pelsonce as she could it."
#
#      "Geaking to have home
#      indo. When the cas
#
# lstm_trial:1, iter:5999/20000 loss:1.5587454283237456
# generated sequence: We cant
#      cried his hown it wruld you teankers, sill younwere, I am one exceli.
#      Hell
#      onc
#
# lstm_trial:1, iter:6099/20000 loss:1.574741541147232
# generated sequence: We flouber. That may so I coll?"
#
#      "It is now, and
#      which you happen it way wish to murtery b
#
# lstm_trial:1, iter:6199/20000 loss:1.576431086063385
# generated sequence: Wite, "he prow addust of Rush my might oth withink to
#      with your down for seent it steat that Mrs
#
# lstm_trial:1, iter:6299/20000 loss:1.5613693237304687
# generated sequence: Wate. A knows and to me dedorminal asknest if behind house fact, Joks proocling out to mait
#      Agem
#
# lstm_trial:1, iter:6399/20000 loss:1.5765643978118897
# generated sequence: When yet one of the curteavied. Whthere for the inforary hrace. "Now specicing. So houst alpervore fo
#
# lstm_trial:1, iter:6499/20000 loss:1.545060259103775
# generated sequence: Whader, recaintt. No sope momed the possactor failing. In well seck by dearing our diciten. I
#      br
#
# lstm_trial:1, iter:6599/20000 loss:1.5460473275184632
# generated sequence: Wair cogain upos upon the latilar.. You wis
#      "which is effing,
#      acroed a fact, wa
#      starto
#
# lstm_trial:1, iter:6699/20000 loss:1.5503870582580566
# generated sequence: We has grast you."
#
#      "Silionce."
#
#      "Juse hhad the knew windly shiPers camatter
#      clainsome
#
# lstm_trial:1, iter:6799/20000 loss:1.565017591714859
# generated sequence: We, rearengr. I found."
#
#      "The memat of at stranger. "It
#      juse arrearys an the povered. I mur
#
# lstm_trial:1, iter:6899/20000 loss:1.5527994525432587
# generated sequence: We oursterd upon who
#      draw, answerentor?
#
#      "you thing rais. He pirtlacoing. Bitty?"
#
#      Wha
#
# lstm_trial:1, iter:6999/20000 loss:1.5755432498455049
# generated sequence: We for once."
#
#      "We Hone's upon the dood. "It is a come plosses confid to be the samplethes. He
#
# lstm_trial:1, iter:7099/20000 loss:1.5639935207366944
# generated sequence: Wave it wnit I as the splent, when any the down persidnal where alone is nisuly hat of a becocton Ona
#
# ...
#
# lstm_trial:2, iter:4099/20000 loss:1.6503132665157318
# generated sequence: What
#      the hall!" he. "Iths alooush light at him BaI high, I gettle mist the plases Wall. No lest
#
# lstm_trial:2, iter:4199/20000 loss:1.5975816559791565
# generated sequence: Won nat lakaned more moming myselled of murn goistas; uppone to
#      his move blaid. "Ivaly nighing b
#
# lstm_trial:2, iter:4299/20000 loss:1.642235300540924
# generated sequence: Ween yow evered lighing juse could be welled was
#      were frist, and have hois of the trieal some in
#
# lstm_trial:2, iter:4399/20000 loss:1.6109804022312164
# generated sequence: Waplen, Treet time
#      swone ame as a grently upon thoubther a kindors--has one to an hos will, case
#
# lstm_trial:2, iter:4499/20000 loss:1.6034511244297027
# generated sequence: Wtrance
#      that that more, but sorry he short, and
#      to ? But than has of your back and deving w
#
# lstm_trial:2, iter:4599/20000 loss:1.6416317760944366
# generated sequence: Wer pissabicosed?" o'te- long ewads Smattly min, for the loted obred on into le
#      it up you gad Le
#
# lstm_trial:2, iter:4699/20000 loss:1.5967184925079345
# generated sequence: Whiis handse, unten for sirs. Daggtsion
#      an this who who liven surnem somonexas bedor
#      when I
#
# lstm_trial:2, iter:4799/20000 loss:1.5989910316467286
# generated sequence: Wden oue crad ty leftle down the sower toung so leftered windight Holmem crainly no wandibed us fers
#
#
# lstm_trial:2, iter:4899/20000 loss:1.6118934881687164
# generated sequence: Wintan exped stoneded of thom to fot
#      markedly
#      ovire to think tho hand gable, Wut a luits im
#
# lstm_trial:2, iter:4999/20000 loss:1.5685863828659057
# generated sequence: Whish the visus sbind to was could evidented herpow javing you had you," said Burked. "He
#      been m
#
# lstm_trial:2, iter:5099/20000 loss:1.572554646730423
# generated sequence: Whish. He was all they of the to?"
#
#      "Well, which was Howtin his is makyonve-glal Watseader, and
#
# lstm_trial:2, iter:5199/20000 loss:1.608631772994995
# generated sequence: Wal. "You," Every buring in had a rist in?"
#
#      The eRst-man upow likes poom. I said thkid?"
#
#
#
# lstm_trial:2, iter:5299/20000 loss:1.5730414485931397
# generated sequence: Werch datilatures!"
#
#      Our he shem he was
#      when the call hair any was as vadged wa the
#      se
#
# lstm_trial:2, iter:5399/20000 loss:1.5732764410972595
# generated sequence: Wall! Holmes," said. There."
#
#      "Miss breakien to expers with for the cording--the some, for say n
#
# lstm_trial:2, iter:5499/20000 loss:1.5878856194019317
# generated sequence: Wall up
#      coming in only with the liphryed of cimtaderan shir eyes cated runger the radeng it mani
#
# lstm_trial:2, iter:5599/20000 loss:1.6119792127609254
# generated sequence: We, which Jobleate in the bring you his camp off cleat to
#      and padente lood he presitict turnedfe
#
# lstm_trial:2, iter:5699/20000 loss:1.566248186826706
# generated sequence: Welsing and epeticulbe baken,
#      take gobed all I am sweed im, backed. To shem note---we has aiguan
#
# lstm_trial:2, iter:5799/20000 loss:1.5727065432071685
# generated sequence: Would lott that he was infost roor aton we afveher, and chanted, whith
#      hapmowaltfacirese a frugh
#
# lstm_trial:2, iter:5899/20000 loss:1.5966477644443513
# generated sequence: Watter one remam oxce. The sqongluble. He stigy. I am all, the oeess it head a condle; when I matnly
#
# lstm_trial:2, iter:5999/20000 loss:1.5776517140865325
# generated sequence: Whom that
#      not fhim me timply longer's feers. At a vient. It's and foll," sear of followt whichs
#
# lstm_trial:2, iter:6099/20000 loss:1.535577379465103
# generated sequence: Wellenzs, and remerpucrion upon the lofe, and it? You'll somet maning about day! Sherl your
#      man
#
# lstm_trial:2, iter:6199/20000 loss:1.5500568115711213
# generated sequence: With two man and feinar is the pienst and a quint to taver which I
#      stance
#      palled bented aga
#
# lstm_trial:2, iter:6299/20000 loss:1.557773985862732
# generated sequence: When your
#      may, and
#      his some of have very cartly le are down his handy which ctuble is
#
#
# lstm_trial:2, iter:6399/20000 loss:1.5569137227535248
# generated sequence: What him. Coppent--way mutned with him expied of had the
#      diriadety over forming.
#
#      "Gery
#
#
# lstm_trial:2, iter:6499/20000 loss:1.5548455393314362
# generated sequence: Wermen.'
#
#      "Loife we that he
#      stone recomprabmine oponed of thlong the six clogrwainy bollies
#
# lstm_trial:2, iter:6599/20000 loss:1.5671728539466858
# generated sequence: Wid at enerieve little marking where bed doic of the booked." I hadds would fatos evidence."
#
#      "W
#
# lstm_trial:2, iter:6699/20000 loss:1.5282019448280335
# generated sequence: Wis' take mined herrow, through what
#      remighture, and
#      Brought was Birker. This mutch. "Wey
#
#
# lstm_trial:2, iter:6799/20000 loss:1.5862922251224518
# generated sequence: Wand atant all the fewn askear poled post of rescrobby cacloged at what know the bfellly papeinably f
#
# lstm_trial:2, iter:6899/20000 loss:1.512241839170456
# generated sequence: We convidal all to miny
#      that for and
#      paper, had brown lont,
#      after the badyed trong him
#
# lstm_trial:2, iter:6999/20000 loss:1.543565423488617
# generated sequence: We't went compinusirad led him and
#      very upon wood he. He greak in you is chare two find and his
# lstm_trial:2, iter:7099/20000 loss:1.5441989243030547
# generated sequence: We a rife the
#      of in it. Breadress
#      but our sentle--eys upon up the moor--quite of gut, a dos
#
# lstm_trial:2, iter:7199/20000 loss:1.5604533970355987
# generated sequence: Wently stecting, and nof bieded a cevers, sirnd, we was And would beer has been frimin to ofraar he w
#
# lstm_trial:2, iter:7299/20000 loss:1.5230566811561586
# generated sequence: W hower lookeave all the worked
#      just be the uny his moment a men of the reir poled and
#      foll
#
# lstm_trial:2, iter:7399/20000 loss:1.5160604643821716
# generated sequence: Were his
#      dif to stepe
#      gaving upon a likicures who rechice detercance ow old bean no side, b
#
# lstm_trial:2, iter:7499/20000 loss:1.520580027103424
# generated sequence: Wellow. There warrand, and that is
#      absuan who handing
#      gote seem before,
#      dresson fror t
#
# lstm_trial:2, iter:7599/20000 loss:1.5188973569869995
# generated sequence: Wery there she?"
#
#      It was than is dribt, was amsminsterger and brother fand myseld, minute his al
#
# lstm_trial:2, iter:7699/20000 loss:1.5154907202720642
# generated sequence: Whreer the other, oure inainel had even our canzed.
#      "You see a
#      oble went my had. I bewercun
#
# lstm_trial:2, iter:7799/20000 loss:1.5166412687301636
# generated sequence: We pressins to catser my exater and disat about the tought, up any
#
#      tsy Ormest in insatial out i
#
# lstm_trial:2, iter:7899/20000 loss:1.5195849323272705
# generated sequence: Wright the Holthing findisast cougl.
#
#      "He reither.  He kother residinustand-geting
#          the
#
# lstm_trial:2, iter:7999/20000 loss:1.4965249347686767
# generated sequence: Wentand,
#      half-roundle wime quise?"
#
#      "It fist so seeplitines.
#
#      I have figurely exast sh
#
# lstm_trial:2, iter:8099/20000 loss:1.5323755526542664
# generated sequence: Whout the ketnned.
#
#       It overdone
#      first being at conclity in a buld. The let his ememt to as
#
# lstm_trial:2, iter:8199/20000 loss:1.5155623042583466
# generated sequence: Where take of the mander fushs withereving such one conulaty worky forcit. Oh.
#
#      "Well bring us w
#
# lstm_trial:2, iter:8299/20000 loss:1.5010689198970795
# generated sequence: Wats fougs, and liftlueds, for I scoke, you warl beak sunce all Jive?"
#
#      Well, Mr. Lrow are not I
#
# lstm_trial:2, iter:8399/20000 loss:1.4828422105312347
# generated sequence: We mester that'e some
#      be the
#      cabsecly cable. But this Bakers was invely
#      after!' said H
#
# lstm_trial:2, iter:8499/20000 loss:1.5175028049945831
# generated sequence: Well I
#      spate a man
#      busting to my I sayman had not sok.
#      She resure me miny were that Cw
#
# lstm_trial:2, iter:8599/20000 loss:1.510438507795334
# generated sequence: Weeg upon his risting and not saw untilyereor, and the advail, and I an once.
#
#      I
#      san at,
#
#
# lstm_trial:2, iter:8699/20000 loss:1.5061592066287994
# generated sequence: Wat of his?"
#
#
#      "Seld my gind clair Alobat, she fatulan care, I thought out a just,
#      alr shou
#
# lstm_trial:2, iter:8799/20000 loss:1.4991675925254822
# generated sequence: What it obvilon from his
#      had confan trounding it
#      not
# e vislbfound
#      us over a Trask
#
#
# lstm_trial:2, iter:8899/20000 loss:1.5056933653354645
# generated sequence: We an
#      Sondress usef it with the call on his reasons. Gover if the tany Masmindable for the later
#
# lstm_trial:2, iter:8999/20000 loss:1.5162800693511962
# generated sequence: Wis sings onatorgy toom. You knew Mr. Drived to cording havinghind than those makity that the gill-ya
#
# lstm_trial:2, iter:9099/20000 loss:1.4778789043426515
# generated sequence: We are very have been the graintry, susen in his dance to could net- clained me, tibed the ruther Mr.
#
# lstm_trial:2, iter:9199/20000 loss:1.4887793266773224
# generated sequence: What two ask him. So not evening
#      in the nasmer, rost did you had seen and villafted it."
#
#      "
#
# lstm_trial:2, iter:9299/20000 loss:1.503777151107788
# generated sequence: What
#      sat Ers that with
#      may snowy as more the sount, by firsting, for I have mysied Mr. Lads
#
# lstm_trial:2, iter:9399/20000 loss:1.4549240374565124
# generated sequence: We adswarding," may, and her outural asknated she tere from his seiristed the round to agantroon."
#
#
#
# lstm_trial:2, iter:9499/20000 loss:1.481449408531189
# generated sequence: Well bearture!' Mimime to was fire, your had newed to ask the only state on sever.
#      Holmes?" give
#
# lstm_trial:2, iter:9599/20000 loss:1.4827679240703582
# generated sequence: Wfited against the, and shoped his some Cobors what quicked the gaps at enterate after the boveremenc
#
# lstm_trial:2, iter:9699/20000 loss:1.5148992228507996
# generated sequence: Well notered affardico your coar turn in that your only his siluge him out my ears
#      man even up.
#
# lstm_trial:2, iter:9799/20000 loss:1.4887360286712648
# generated sequence: Was south Smonten? We cantectorry broshing of could be ergars mile the erasinal up my turner open whi
#
# lstm_trial:2, iter:9899/20000 loss:1.4811203956604004
# generated sequence: We to as my  owing mine we had had great. Mror
#      the dispecioale
#      eyember distrue he way nare,
#
# lstm_trial:2, iter:9999/20000 loss:1.4989628267288209
# generated sequence: We fams. Sready thrible, eving, "would not been the earnew," said she such told, or with senterstr,
#
#
# lstm_trial:2, iter:10099/20000 loss:1.4877664518356324
# generated sequence: Wald know
#      meshed your upwe hal, with a coffined to he feet an eary a casped. He has not very ris
#
# lstm_trial:2, iter:10199/20000 loss:1.4802058839797974
# generated sequence: Was them that peept by with the Comictants which I have when an ears, with me this face her ald to-my
#
# lstm_trial:2, iter:10299/20000 loss:1.4941133499145507
# generated sequence: Waters. The drive, sir, Ensops. Her restide a room, appassians and the ryot of his long the
#      hat?
#
# lstm_trial:2, iter:10399/20000 loss:1.4749273216724397
# generated sequence: We ask his chatefonce. When we walked, swite I as husers?"
#
#      "You're bethe expicted to coulds wit
#
# lstm_trial:2, iter:10499/20000 loss:1.470239932537079
# generated sequence: We hands as dement
#
#      deciden. But where I shey he had romp the sleellys which ttrages bristed
#
# lstm_trial:2, iter:10599/20000 loss:1.4651159644126892
# generated sequence: Wh, sir
#      address account at
#      never days to confate
#      the patirutable. "Abstere firgesinalt
#
# lstm_trial:2, iter:10699/20000 loss:1.4815900826454163
# generated sequence: W anytant the pert blate inbodengity when I go?"
#
#      "And he was upon Mr. Of anyous had to
#      suc
#
# lstm_trial:2, iter:10799/20000 loss:1.4713662767410278
# generated sequence: Welw, the from poschty-shops," he adviched to see upon it. What armous spoke," said, with a pointy re
#
# lstm_trial:2, iter:10899/20000 loss:1.520955229997635
# generated sequence: Were well, Watsons and assormed whose have been. At peninew of coustion wimb
#      in revanqurtly inde
#
# lstm_trial:2, iter:10999/20000 loss:1.4851657021045686
# generated sequence: What were well, make suggeagen. The Atch my
#      time, anywhand I went to
#      we a though and silest
#
# lstm_trial:2, iter:11099/20000 loss:1.4653078055381774
# generated sequence: We would dark, with the wricker to Mr. Oneming on the Mudged hoper within overnice,
#      do the few i
#
# lstm_trial:2, iter:11199/20000 loss:1.4791022109985352
# generated sequence: What to that all, and I point."
#
#      "In it was
#      inchession om."
#
#      "Go my police liment pass
#
# lstm_trial:2, iter:11299/20000 loss:1.4821070969104766
# generated sequence: What if you got thouged of the exfertable Deted that I mean it villededeans I know hereling of the ed
#
# lstm_trial:2, iter:11399/20000 loss:1.4577490746974946
# generated sequence: Weature a gampere and even upon the vobfication that all to step of the fame," said Holmes Ross of ev
#
# lstm_trial:2, iter:11499/20000 loss:1.4489727067947387
# generated sequence: Well, and then his a dobver, at a fact rettain lembled that it was chatidey it us bring my gread Poun
#
# lstm_trial:2, iter:11599/20000 loss:1.4727385580539702
# generated sequence: Wall no handling have gong forged. But door with the oppinizal shoth as jum, that the phe rave door s
#
# lstm_trial:2, iter:11699/20000 loss:1.4728899443149566
# generated sequence: What three seen firghouse why was so, but the first continining the studywark Bakers and calls, no ca
# lstm_trial:2, iter:11799/20000 loss:1.454370836019516
# generated sequence: We seem the zarsel was the whole if his despartiusler affains but one treaw imposs bitten for
#      to
#
# lstm_trial:2, iter:11899/20000 loss:1.4822352886199952
# generated sequence: Witton the expectable and helner
#      at mone present. There is ampossibly this lounch with happly. I
#
# lstm_trial:2, iter:11999/20000 loss:1.418679918050766
# generated sequence: Watton."
#
#      "May or last beyore?"
#
#      "What
#      is nouse, for the broub his thouthan in his
#
#
# lstm_trial:2, iter:12099/20000 loss:1.4477794468402863
# generated sequence: Walmly, the Foration at him to this. "We she is you, strudg, sir, lightore best derest alreading mood
#
# lstm_trial:2, iter:12199/20000 loss:1.4685896265506744
# generated sequence: Wilspare him.
#      Fner and the polied that they was nothing.
#
#      "Geverson which O, he was heard f
#
# lstm_trial:2, iter:12299/20000 loss:1.4586278653144837
# generated sequence: Well."
#
#      The man she he rutcht good bett chrangh. It is one thought, but by crim, and the procees
#
# lstm_trial:2, iter:12399/20000 loss:1.4976275491714477
# generated sequence: Wy to sey that is plall me spayed two sow indeeved a very fatts.
#
#      "Yes, I on the tcreture sound-
#
# lstm_trial:2, iter:12499/20000 loss:1.4254669880867004
# generated sequence: Well, my lady. No took last
#      mort, toged and
#      sot has her actu-the
#      receot his to doubt,
#
# lstm_trial:2, iter:12599/20000 loss:1.4410021960735322
# generated sequence: Watton which taking now, and days, up
#      the to open to "He had not it is is purse more that it id
#
# lstm_trial:2, iter:12699/20000 loss:1.4402649104595184
# generated sequence: Walder went it one man burns."
#
#      "I'm what is ablandn's shon or hanted. It would twiring it," gat
#
# lstm_trial:2, iter:12799/20000 loss:1.4379593670368194
# generated sequence: Well, my which drees, let lighide never said indiched at the witling
#      is by it
#      wive up a man
#
# lstm_trial:2, iter:12899/20000 loss:1.449021965265274
# generated sequence: Was anster on the extray? Why, who packed! face dark, 1885-curdow withon his mys passed to be
#      wh
#
# lstm_trial:2, iter:12999/20000 loss:1.4145315313339233
# generated sequence: Well, then am you uses care. But, as clear. Of his soon our buanted by iman on the noterive you will

# %%
plt.title("Average Loss Over 20,000 Iterations")
plt.xlabel('iters')
plt.ylabel('loss')
plt.plot(mean_losses_rnn)
plt.plot(mean_losses_lstm)
plt.legend(['RNN', 'LSTM'])
plt.show()

# %%
print(eval_step(net_rnn, predicted_len=600))

# %%
print(eval_step(net_lstm, predicted_len=600))
